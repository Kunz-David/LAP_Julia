# %% [markdown]
# # Registration Functions Showcase

# %% [markdown]
# In this example page I will show how to work with the registration algorithms `lap`, `pflap`, `sparse_lap` and `sparse_pflap`.

# %% [markdown]
# I will generate some images to show the workings and function calls.

# %%
# using the package
using LAP_julia;

# default arguments:
img, imgw, flow = gen_init();

# %% [markdown]
# See the `Basic Interaction` section or the `Public Documentation` for more advanced input generation

# %% [markdown]
# __These are the differences between the `target` (`img`) and `source` (`imgw`) images.__

# %%
imgoverlay(img, imgw, figtitle="Target vs Source")
# Out:
# PyPlot.Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ## Full LAP Methods

# %% [markdown]
# These functions are from the algorithms from the paper [Local All-Pass Geometric Deformations](https://www.researchgate.net/publication/320574179_Local_All-Pass_Geometric_Deformations).

# %% [markdown]
# ### `lap` function

# %%
# set a filter half size, which is larger than the default max displacement: 10 used in gen_init
fhs = 15;
flow_est, source_reg = lap(img, imgw, fhs);

# %% [markdown]
# This gives us a estimation of the flow and the registered source image

# %% [markdown]
# __This is what the registered source image looks like:__

# %%
imgoverlay(img, source_reg, figtitle="lap: Target vs Registered Source")
# Out:
# PyPlot.Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ### `pflap` function

# %%
flow_est, source_reg = pflap(img, imgw);
# Out:
# ###################
# ITERATION: 1
# filter_half_size: 64
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, repeating filter size
# inner loop iter: 3
# 	 status: success, repeating filter size
# ###################
# ITERATION: 2
# filter_half_size: 32
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 3
# filter_half_size: 16
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 4
# filter_half_size: 8
# inner loop iter: 1
# NaN count: 69
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 5
# filter_half_size: 4
# inner loop iter: 1
# NaN count: 892
# 	 status: success, next filter size
# ###################
# ITERATION: 6
# filter_half_size: 2
# inner loop iter: 1
# NaN count: 2334
# 	 status: success, next filter size
# ###################
# ITERATION: 7
# filter_half_size: 1
# inner loop iter: 1
# NaN count: 5889
# 	 status: success, repeating filter size
# inner loop iter: 2
# NaN count: 4713
# 	 status: success, next filter size

# %% [markdown]
# This gives us a estimation of the flow and the registered source image

# %% [markdown]
# __This is what the registered source image looks like:__

# %%
imgoverlay(img, source_reg, figtitle="pflap: Target vs Registered Source")
# Out:
# PyPlot.Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ## Sparse LAP Methods

# %% [markdown]
# These functions are insired by the `lap` and `pflap` functions. The difference being only some displacement vectors are calculated and
# the result is fit into a global deformation.

# %% [markdown]
# ### `sparse_lap` function

# %%
# set a filter half size, which is larger than the default max displacement: 10 used in gen_init
fhs = 15;
flow_est, source_reg = lap(img, imgw, fhs);

# %% [markdown]
# This gives us a estimation of the flow and the registered source image

# %% [markdown]
# __This is what the registered source image looks like:__

# %%
imgoverlay(img, source_reg, figtitle="lap: Target vs Registered Source")
# Out:
# PyPlot.Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ### `pflap` function

# %%
flow_est, source_reg = pflap(img, imgw);
# Out:
# ###################
# ITERATION: 1
# filter_half_size: 64
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, repeating filter size
# inner loop iter: 3
# 	 status: success, repeating filter size
# ###################
# ITERATION: 2
# filter_half_size: 32
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 3
# filter_half_size: 16
# inner loop iter: 1
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 4
# filter_half_size: 8
# inner loop iter: 1
# NaN count: 69
# 	 status: success, repeating filter size
# inner loop iter: 2
# 	 status: success, next filter size
# ###################
# ITERATION: 5
# filter_half_size: 4
# inner loop iter: 1
# NaN count: 892
# 	 status: success, next filter size
# ###################
# ITERATION: 6
# filter_half_size: 2
# inner loop iter: 1
# NaN count: 2334
# 	 status: success, next filter size
# ###################
# ITERATION: 7
# filter_half_size: 1
# inner loop iter: 1
# NaN count: 5889
# 	 status: success, repeating filter size
# inner loop iter: 2
# NaN count: 4713
# 	 status: success, next filter size

# %% [markdown]
# This gives us a estimation of the flow and the registered source image

# %% [markdown]
# __This is what the registered source image looks like:__

# %%
imgoverlay(img, source_reg, figtitle="pflap: Target vs Registered Source")
# Out:
# PyPlot.Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
