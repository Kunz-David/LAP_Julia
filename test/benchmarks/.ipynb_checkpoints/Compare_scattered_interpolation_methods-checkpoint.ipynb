# %%
using WebIO
WebIO.install_jupyter_nbextension()
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-6296698477504491659\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-694793250951119192\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-6296698477504491659\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Info: Installing Jupyter WebIO extension...
# │   cmd = `/Users/MrTrololord/.julia/conda/3/bin/jupyter nbextension install --user /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/bundles/webio-jupyter-notebook.js`
# └ @ WebIO /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/jupyter.jl:237
# Up to date: /Users/MrTrololord/Library/Jupyter/nbextensions/webio-jupyter-notebook.js
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable <the entry point> --user
#
# ┌ Info: Enabling Jupyter WebIO extension...
# │   cmd = `/Users/MrTrololord/.julia/conda/3/bin/jupyter nbextension enable --user webio-jupyter-notebook`
# └ @ WebIO /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/jupyter.jl:241
# Enabling notebook extension webio-jupyter-notebook...
#       - Validating: OK

# %%
using Dierckx, ScatteredInterpolation, PyPlot, Random, BenchmarkTools, DataFrames, TableView;
import LAP_julia: helpers.mse, helpers.vec_len, helpers.angle_rmse, helpers.angle_mae, gen_tiled_flow, showflow
import PyCall: PyObject

# %% [markdown]
# ## Functions to be tested

# %%
# methods that work well and will be tested: Thin splate spline (Polyharmonic(2)), Multiquadratic
"""
    test_scatter(points, samples, smoothness; method)

`points` should be an n×k matrix, where n is dimension of the sampled space and k is the number of points. This means that each column in the matrix defines one point.
`samples` is an k×m array, where k is the number of sampled points (same as for points) and m is the dimension of the sampled data.

"""
function test_scatter(flow_size, points, samples; method)
    gridPoints = meshgrid(flow_size...)'
    itp = interpolate(method, points, samples);
    interpolated = ScatteredInterpolation.evaluate(itp, gridPoints)
    gridded = reshape(interpolated, flow_size)
    return gridded
end



function test_dier(flow_size, x, y, z1, z2)
    storage = 1000
    spl1 = Spline2D(x, y, z1; w=ones(length(x)), kx=1, ky=1, s=storage)
    real1 = evalgrid(spl1, 1:flow_size[1], 1:flow_size[2])

    spl2 = Spline2D(x, y, z2; w=ones(length(x)), kx=1, ky=1, s=storage)
    imag1 = evalgrid(spl2, 1:flow_size[1], 1:flow_size[2])

    gridded = real1 .+ imag1 .* im
    return gridded
end


meshgrid(x, y) = [repeat(x, outer=length(y)) repeat(y, inner=length(x))];
meshgrid(x::Real, y::Real) = [repeat(1:x, outer=y) repeat(1:y, inner=x)];

# %% [markdown]
# ## Prepare DataFrame

# %%
scatter_interp_bench = DataFrame(
                                Index = Int[],
                                Method = String[],
                                Mode = String[],
                                Point_count = Int[],
                                Median_speed = Float64[],
                                Magnitude_of_MSE = Float64[],
                                Angle_RMS = Float64[],
                                Angle_mean = Float64[],
                                Benchmark = BenchmarkTools.Trial[],
                                Truth_flow = PyObject[],
                                Method_flow = PyObject[],
                                Scatter_points = PyObject[]
                                )

# df = scatter_interp_bench

# test output
out = showtable(df)
# Out:
# Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[""], Dict{Symbol,Any}(:style => Dict("height" => "0","padding" => "0","background-color" => "#F5F7F7","color" => "#1c1f20","font-family" => "-apple-system, BlinkMacSystemFont, \"Segoe UI\", Roboto, Oxygen-Sans, Ubuntu, Cantarell, \"Helvetica Neue\", sans-serif"))), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Symbol,Any}(:id => "grid-7d67d85c",:className => "ag-theme-balham",:style => Dict("height" => "50px","width" => "100%")))], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("onCellKeyDown" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onRowClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellDoubleClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellFocused" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing)), Set(String[]), nothing, Asset[Asset("js", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/src/rowNumberRenderer.js"), Asset("js", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid.js"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid.css"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid-light.css"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid-dark.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x0000000118966410, Task (runnable) @0x0000000118966410), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (RowNumberRenderer,agGrid){var gridOptions={\"onCellFocused\":(function (ev){var x={}; (ev.rowIndex!==undefined) ? (x[\"rowIndex\"]=(ev.rowIndex+1)) : undefined; (ev.colDef!==undefined) ? (x[\"column\"]=ev.colDef.headerName) : undefined; return WebIO.setval({\"name\":\"onCellFocused\",\"scope\":\"9524724700223240867\",\"id\":\"ob_39\",\"type\":\"observable\"},x)}),\"onCellValueChanged\":(function (){return }),\"onCellDoubleClicked\":(function (ev){var x={}; (ev.rowIndex!==undefined) ? (x[\"rowIndex\"]=(ev.rowIndex+1)) : undefined; (ev.colDef!==undefined) ? (x[\"column\"]=ev.colDef.headerName) : undefined; return WebIO.setval({\"name\":\"onCellDoubleClicked\",\"scope\":\"9524724700223240867\",\"id\":\"ob_37\",\"type\":\"observable\"},x)}),\"multiSortKey\":\"ctrl\",\"columnDefs\":[{\"filter\":false,\"editable\":false,\"headerTooltip\":\"\",\"field\":\"__row__\",\"headerName\":\"Row\",\"sortable\":true,\"type\":\"numericColumn\",\"cellRenderer\":\"rowNumberRenderer\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Int64\",\"field\":\"Index\",\"headerName\":\"Index\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"String\",\"field\":\"Method\",\"headerName\":\"Method\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"String\",\"field\":\"Mode\",\"headerName\":\"Mode\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Int64\",\"field\":\"Point_count\",\"headerName\":\"Point_count\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Median_speed\",\"headerName\":\"Median_speed\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Magnitude_of_MSE\",\"headerName\":\"Magnitude_of_MSE\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Angle_RMS\",\"headerName\":\"Angle_RMS\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Angle_mean\",\"headerName\":\"Angle_mean\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"BenchmarkTools.Trial\",\"field\":\"Benchmark\",\"headerName\":\"Benchmark\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"PyObject\",\"field\":\"Truth_flow\",\"headerName\":\"Truth_flow\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"PyObject\",\"field\":\"Method_flow\",\"headerName\":\"Method_flow\",\"sortable\ ...

# %% [markdown]
# # Test

# %%
# parameters:
test_count = 10
flow_size = (200, 200)


Methods = ["Dier",
           "Scatter-Thin_plate_spline",
           "Scatter-Multiquadratic"]

Modes = ["Random_points",
         "Semigridded",
         "Gridded"]

Point_counts = [9,
                16,
                25,
                49,
                81,
                100,
                144]

# store run errors of methods
# each entry has: (method name, flow, inds, error output)
errors = []

let
    index = 0

    for test in 1:test_count
        flow = gen_tiled_flow(flow_size, 30, 40)
        for point_count in Point_counts
            for point_mode in Modes
                inds = gen_rand_points(flow, point_count, point_mode)
                for method in Methods
                        x = [ind[1] for ind in inds]
                        y = [ind[2] for ind in inds]
                    if method == "Dier"
                        # set inputs
                        z1 = [real(flow[ind]) for ind in inds]
                        z2 = [imag(flow[ind]) for ind in inds]
                        # check if method errors, if yes then log and skip
                        try
                            method_flow = test_dier(flow_size, x, y, z1, z2)
                        catch e
                            push!(errors, (method, flow, inds, e))
                            continue
                        end
                        # eval with current input
                        method_flow = test_dier(flow_size, x, y, z1, z2)
                        # do a benchmark
                        bench = @benchmark test_dier($flow_size, $x, $y, $z1, $z2)
                    elseif method == "Scatter-Thin_plate_spline"
                        # set inputs
                        points = reshape([ind[i] for i=1:length(inds[1]) for ind=inds], length(inds), length(inds[1]))'
                        samples = [flow[I] for I in inds]
                        # check if method errors, if yes then log and skip
                        try
                            method_flow = test_scatter(flow_size, points, samples; method = Polyharmonic(2))
                        catch e
                            push!(errors, (method, flow, inds, e))
                            continue
                        end
                        # eval with current input
                        method_flow = test_scatter(flow_size, points, samples; method = Polyharmonic(2))
                        # do a benchmark
                        bench = @benchmark test_scatter($flow_size, $points, $samples; method = $Polyharmonic(2))
                    elseif method == "Scatter-Multiquadratic"
                        # set inputs
                        points = reshape([ind[i] for i=1:length(inds[1]) for ind=inds], length(inds), length(inds[1]))'
                        samples = [flow[I] for I in inds]
                        # check if method errors, if yes then log and skip
                        try
                            method_flow = test_scatter(flow_size, points, samples; method = Multiquadratic(2))
                        catch e
                            push!(errors, (method, flow, inds, e))
                            continue
                        end
                        # eval with current input
                        method_flow = test_scatter(flow_size, points, samples; method = Multiquadratic(2))
                        # do a benchmark
                        bench = @benchmark test_scatter($flow_size, $points, $samples; method = $Multiquadratic(2))
                    end
                    # ADD TO DATA FRAME
                    index = index + 1
                    println("at index ", index)
                    push!(df, Dict(:Index => index,
                                   :Method => method,
                                   :Mode => point_mode,
                                   :Point_count => point_count,
                                   :Median_speed => median(bench).time / (10^6),
                                   :Magnitude_of_MSE => vec_len(mse(method_flow, flow)),
                                   :Angle_RMS => angle_rmse(method_flow, flow),
                                   :Angle_mean => angle_mae(method_flow, flow),
                                   :Benchmark => bench,
                                   :Truth_flow => showflow(flow, figtitle="Truth flow", ret="PyObject"),
                                   :Method_flow => showflow(method_flow, figtitle=(method * " flow"), ret="PyObject"),
                                   :Scatter_points => scatter(x, y, marker=:x)
                        ))
                    plt.close()
                    plt.close()
                    plt.close()
                end
            end
        end
    end
end # let
# Out:
# at index 1
# at index 2
# at index 3
# at index 4
# at index 5
# at index 6
# at index 7
# at index 8
# at index 9
# at index 10
# at index 11
# at index 12
# at index 13
# at index 14
# at index 15
# at index 16
# at index 17
# at index 18
# at index 19
# at index 20
# at index 21
# at index 22
# at index 23
# at index 24
# at index 25
# at index 26
# at index 27
# at index 28
# at index 29
# at index 30
# at index 31
# at index 32
# at index 33
# at index 34
# at index 35
# at index 36
# at index 37
# at index 38
# at index 39
# at index 40
# at index 41
# at index 42
# at index 43
# at index 44
# at index 45
# at index 46
# at index 47
# at index 48
# at index 49
# at index 50
# at index 51
# at index 52
# at index 53
# at index 54
# at index 55
# at index 56
# at index 57
# at index 58
# at index 59
# at index 60
# at index 61
# at index 62
# at index 63
# at index 64
# at index 65
# at index 66
# at index 67
# at index 68
# at index 69
# at index 70
# at index 71
# at index 72
# at index 73
# at index 74
# at index 75
# at index 76
# at index 77
# at index 78
# at index 79
# at index 80
# at index 81
# at index 82
# at index 83
# at index 84
# at index 85
# at index 86
# at index 87
# at index 88
# at index 89
# at index 90
# at index 91
# at index 92
# at index 93
# at index 94
# at index 95
# at index 96
# at index 97
# at index 98
# at index 99
# at index 100
# at index 101
# at index 102
# at index 103
# at index 104
# at index 105
# at index 106
# at index 107
# at index 108
# at index 109
# at index 110
# at index 111
# at index 112
# at index 113
# at index 114
# at index 115
# at index 116
# at index 117
# at index 118
# at index 119
# at index 120
# at index 121
# at index 122
# at index 123
# at index 124
# at index 125
# at index 126
# at index 127
# at index 128
# at index 129
# at index 130
# at index 131
# at index 132
# at index 133
# at index 134
# at index 135
# at index 136
# at index 137
# at index 138
# at index 139
# at index 140
# at index 141
# at index 142
# at index 143
# at index 144
# at index 145
# at index 146
# at index 147
# at index 148
# at index 149
# at index 150
# at index 151
# at index 152
# at index 153
# at index 154
# at index 155
# at index 156
# at index 157
# at index 158
# at index 159
# at index 160
# at index 161
# at index 162
# at index 163
# at index 164
# at index 165
# at index 166
# at index 167
# at index 168
# at index 169
# at index 170
# at index 171
# at index 172
# at index 173
# at index 174
# at index 175
# at index 176
# at index 177
# at index 178
# at index 179
# at index 180
# at index 181
# at index 182
# at index 183
# at index 184
# at index 185
# at index 186
# at index 187
# at index 188
# at index 189
# at index 190
# at index 191
# at index 192
# at index 193
# at index 194
# at index 195
# at index 196
# at index 197
# at index 198
# at index 199
# at index 200
# at index 201
# at index 202
# at index 203
# at index 204
# at index 205
# at index 206
# at index 207
# at index 208
# at index 209
# at index 210
# at index 211
# at index 212
# at index 213
# at index 214
# at index 215
# at index 216
# at index 217
# at index 218
# at index 219
# at index 220
# at index 221
# at index 222
# at index 223
# at index 224
# at index 225
# at index 226
# at index 227
# at index 228
# at index 229
# at index 230
# at index 231
# at index 232
# at index 233
# at index 234
# at index 235
# at index 236
# at index 237
# at index 238
# at index 239
# at index 240
# at index 241
# at index 242
# at index 243
# at index 244
# at index 245
# at index 246
# at index 247
# at index 248
# at index 249
# at index 250
# at index 251
# at index 252
# at index 253
# at index 254
# at index 255
# at index 256
# at index 257
# at index 258
# at index 259
# at index 260
# at index 261
# at index 262
# at index 263
# at index 264
# at index 265
# at index 266
# at index 267
# at index 268
# at index 269
# at index 270
# at index 271
# at index 272
# at index 273
# at index 274
# at index 275
# at index 276
# at index 277
# at index 278
# at index 279
# at index 280
# at index 281
# at index 282
# at index 283
# at index 284
# at index 285
# at index 286
# at index 287
# at index 288
# at index 289
# at index 290
# at index 291
# at index 292
# at index 293
# at index 294
# at index 295
# at index 296
# at index 297
# at index 298
# at index 299
# at index 300
# at index 301
# at index 302
# at index 303
# at index 304
# at index 305
# at index 306
# at index 307
# at index 308
# at index 309
# at index 310
# at index 311
# at index 312
# at index 313
# at index 314
# at index 315
# at index 316
# at index 317
# at index 318
# at index 319
# at index 320
# at index 321
# at index 322
# at index 323
# at index 324
# at index 325
# at index 326
# at index 327
# at index 328
# at index 329
# at index 330
# at index 331
# at index 332
# at index 333
# at index 334
# at index 335
# at index 336
# at index 337
# at index 338
# at index 339
# at index 340
# at index 341
# at index 342
# at index 343
# at index 344
# at index 345
# at index 346
# at index 347
# at index 348
# at index 349
# at index 350
# at index 351
# at index 352
# at index 353
# at index 354
# at index 355
# at index 356
# at index 357
# at index 358
# at index 359
# at index 360
# at index 361
# at index 362
# at index 363
# at index 364
# at index 365
# at index 366
# at index 367
# at index 368
# at index 369
# at index 370
# at index 371
# at index 372
# at index 373
# at index 374
# at index 375
# at index 376
# at index 377
# at index 378
# at index 379
# at index 380
# at index 381
# at index 382
# at index 383
# at index 384
# at index 385
# at index 386
# at index 387
# at index 388
# at index 389
# at index 390
# at index 391
# at index 392
# at index 393
# at index 394
# at index 395
# at index 396
# at index 397
# at index 398
# at index 399
# at index 400
# at index 401
# at index 402
# at index 403
# at index 404
# at index 405
# at index 406
# at index 407
# at index 408
# at index 409
# at index 410
# at index 411
# at index 412
# at index 413
# at index 414
# at index 415
# at index 416
# at index 417
# at index 418
# at index 419
# at index 420
# at index 421
# at index 422
# at index 423
# at index 424
# at index 425
# at index 426
# at index 427
# at index 428
# at index 429
# at index 430
# at index 431
# at index 432
# at index 433
# at index 434
# at index 435
# at index 436
# at index 437
# at index 438
# at index 439
# at index 440
# at index 441
# at index 442
# at index 443
# at index 444
# at index 445
# at index 446
# at index 447
# at index 448
# at index 449
# at index 450
# at index 451
# at index 452
# at index 453
# at index 454
# at index 455
# at index 456
# at index 457
# at index 458
# at index 459
# at index 460
# at index 461
# at index 462
# at index 463
# at index 464
# at index 465
# at index 466
# at index 467
# at index 468
# at index 469
# at index 470
# at index 471
# at index 472
# at index 473
# at index 474
# at index 475
# at index 476
# at index 477
# at index 478
# at index 479
# at index 480
# at index 481
# at index 482
# at index 483
# at index 484
# at index 485
# at index 486
# at index 487
# at index 488
# at index 489
# at index 490
# at index 491
# at index 492
# at index 493
# at index 494
# at index 495
# at index 496
# at index 497
# at index 498
# at index 499
# at index 500
# at index 501
# at index 502
# at index 503
# at index 504
# at index 505
# at index 506
# at index 507
# at index 508
# at index 509
# at index 510
# at index 511
# at index 512
# at index 513
# at index 514
# at index 515
# at index 516
# at index 517
# at index 518
# at index 519
# at index 520
# at index 521
# at index 522
# at index 523
# at index 524
# at index 525
# at index 526
# at index 527
# at index 528
# at index 529
# at index 530
# at index 531
# at index 532
# at index 533
# at index 534
# at index 535
# at index 536
# at index 537
# at index 538
# at index 539
# at index 540
# at index 541
# at index 542
# at index 543
# at index 544
# at index 545
# at index 546
# at index 547
# at index 548
# at index 549
# at index 550
# at index 551
# at index 552
# at index 553
# at index 554
# at index 555
# at index 556
# at index 557
# at index 558
# at index 559
# at index 560
# at index 561
# at index 562
# at index 563
# at index 564
# at index 565
# at index 566
# at index 567
# at index 568
# at index 569
# at index 570
# at index 571
# at index 572
# at index 573
# at index 574
# at index 575
# at index 576
# at index 577
# at index 578
# at index 579
# at index 580
# at index 581
# at index 582
# at index 583
# at index 584
# at index 585
# at index 586
# at index 587
# at index 588
# at index 589
# at index 590
# at index 591
# at index 592
# at index 593
# at index 594
# at index 595
# at index 596
# at index 597
# at index 598
# at index 599
# at index 600
# at index 601
# at index 602
# at index 603
# at index 604
# at index 605
# at index 606
# at index 607
# at index 608
# at index 609
# at index 610
# at index 611
# at index 612
# at index 613
# at index 614
# at index 615
# at index 616
# at index 617
# at index 618
# at index 619
# at index 620
# at index 621
# at index 622
# at index 623
# at index 624
# at index 625
# at index 626
# at index 627
# at index 628
# at index 629

# %%
errors[1][]
# Out:
# 1-element Array{Any,1}:
#  ("Scatter-Multiquadratic", Complex{Float64}[18.069695637611748 - 13.286185622794248im 17.92267336535167 - 13.279790073112146im … 3.4722895669132736 + 0.1323725074050942im 3.707154910987307 + 0.30065016328583744im; 17.66714684370262 - 13.179435195638577im 17.524073929058257 - 13.172476488505227im … 3.2307591129747353 + 0.07144723959038175im 3.459622449404594 + 0.23563051964904033im; … ; 8.542737188318785 + 20.62798695829258im 8.21270708847751 + 20.360411351151132im … -2.7553459862597434 + 16.748122097414686im -2.7176593327451273 + 16.68371828036553im; 8.412392474809161 + 20.56340885557547im 8.079016839820166 + 20.296957759529608im … -2.733229894198988 + 16.736674051845963im -2.6923095124330487 + 16.672312249751265im], CartesianIndex{2}[CartesianIndex(92, 88), CartesianIndex(108, 61), CartesianIndex(80, 186), CartesianIndex(78, 63), CartesianIndex(8, 10), CartesianIndex(79, 47), CartesianIndex(55, 79), CartesianIndex(99, 182), CartesianIndex(200, 76), CartesianIndex(60, 44)  …  CartesianIndex(71, 18), CartesianIndex(190, 60), CartesianIndex(90, 12), CartesianIndex(90, 55), CartesianIndex(189, 33), CartesianIndex(60, 120), CartesianIndex(142, 184), CartesianIndex(19, 83), CartesianIndex(35, 115), CartesianIndex(132, 193)], LinearAlgebra.SingularException(100))

# %%
showtable(df)
# Out:
# Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[""], Dict{Symbol,Any}(:style => Dict("height" => "0","padding" => "0","background-color" => "#F5F7F7","color" => "#1c1f20","font-family" => "-apple-system, BlinkMacSystemFont, \"Segoe UI\", Roboto, Oxygen-Sans, Ubuntu, Cantarell, \"Helvetica Neue\", sans-serif"))), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Symbol,Any}(:id => "grid-023edbee",:className => "ag-theme-balham",:style => Dict("height" => "500px","width" => "100%")))], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("onCellKeyDown" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onRowClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellDoubleClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellClicked" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing),"onCellFocused" => (Observable{Any} with 0 listeners. Value:
# nothing, nothing)), Set(String[]), nothing, Asset[Asset("js", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/src/rowNumberRenderer.js"), Asset("js", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid.js"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid.css"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid-light.css"), Asset("css", nothing, "/Users/MrTrololord/.julia/packages/TableView/CxWLO/deps/ag-grid-22.1.0/ag-grid-dark.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x000000011867e890, Task (runnable) @0x000000011867e890), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (RowNumberRenderer,agGrid){var gridOptions={\"onCellFocused\":(function (ev){var x={}; (ev.rowIndex!==undefined) ? (x[\"rowIndex\"]=(ev.rowIndex+1)) : undefined; (ev.colDef!==undefined) ? (x[\"column\"]=ev.colDef.headerName) : undefined; return WebIO.setval({\"name\":\"onCellFocused\",\"scope\":\"586981644539482488\",\"id\":\"ob_29\",\"type\":\"observable\"},x)}),\"onCellValueChanged\":(function (){return }),\"onCellDoubleClicked\":(function (ev){var x={}; (ev.rowIndex!==undefined) ? (x[\"rowIndex\"]=(ev.rowIndex+1)) : undefined; (ev.colDef!==undefined) ? (x[\"column\"]=ev.colDef.headerName) : undefined; return WebIO.setval({\"name\":\"onCellDoubleClicked\",\"scope\":\"586981644539482488\",\"id\":\"ob_27\",\"type\":\"observable\"},x)}),\"multiSortKey\":\"ctrl\",\"columnDefs\":[{\"filter\":false,\"editable\":false,\"headerTooltip\":\"\",\"field\":\"__row__\",\"headerName\":\"Row\",\"sortable\":true,\"type\":\"numericColumn\",\"cellRenderer\":\"rowNumberRenderer\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Int64\",\"field\":\"Index\",\"headerName\":\"Index\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"String\",\"field\":\"Method\",\"headerName\":\"Method\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"String\",\"field\":\"Mode\",\"headerName\":\"Mode\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Int64\",\"field\":\"Point_count\",\"headerName\":\"Point_count\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Median_speed\",\"headerName\":\"Median_speed\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Magnitude_of_MSE\",\"headerName\":\"Magnitude_of_MSE\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Angle_RMS\",\"headerName\":\"Angle_RMS\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":\"agNumberColumnFilter\",\"editable\":false,\"headerTooltip\":\"Float64\",\"field\":\"Angle_mean\",\"headerName\":\"Angle_mean\",\"sortable\":true,\"type\":\"numericColumn\",\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"BenchmarkTools.Trial\",\"field\":\"Benchmark\",\"headerName\":\"Benchmark\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"PyObject\",\"field\":\"Truth_flow\",\"headerName\":\"Truth_flow\",\"sortable\":true,\"type\":null,\"resizable\":true},{\"filter\":true,\"editable\":false,\"headerTooltip\":\"PyObject\",\"field\":\"Method_flow\",\"headerName\":\"Method_flow\",\"sortable\": ...

# %%
small_point_count = 50
for method in Methods
    println("***** ",method, " *****")
    display(describe(df[(df.Point_count .< small_point_count) .& (df.Method .== method), :]))
end

#df[(df.Index .== 1) .& (df.Point_count .== 9), :].Median_speed
# Out:
# 12×8 DataFrame. Omitted printing of 3 columns
# │ Row │ variable         │ mean    │ min      │ median  │ max         │
# │     │ Symbol           │ Union…  │ Any      │ Union…  │ Any         │
# ├─────┼──────────────────┼─────────┼──────────┼─────────┼─────────────┤
# │ 1   │ Index            │ 143.5   │ 1        │ 143.5   │ 286         │
# │ 2   │ Method           │         │ Dier     │         │ Dier        │
# │ 3   │ Mode             │         │ Gridded  │         │ Semigridded │
# │ 4   │ Point_count      │ 24.75   │ 9        │ 20.5    │ 49          │
# │ 5   │ Median_speed     │ 1.86543 │ 1.64025  │ 1.75958 │ 2.95999     │
# │ 6   │ Magnitude_of_MSE │ 28.8691 │ 0.508992 │ 24.1616 │ 143.708     │
# │ 7   │ Angle_RMS        │ 91.1949 │ 48.7816  │ 79.5886 │ 164.12      │
# │ 8   │ Angle_mean       │ 56.936  │ 28.9908  │ 53.2036 │ 124.452     │
# │ 9   │ Benchmark        │         │          │         │             │
# │ 10  │ Truth_flow       │         │          │         │             │
# │ 11  │ Method_flow      │         │          │         │             │
# │ 12  │ Scatter_points   │         │          │         │             │
# ***** Dier *****
# 12×8 DataFrame. Omitted printing of 4 columns
# │ Row │ variable         │ mean    │ min                       │ median  │
# │     │ Symbol           │ Union…  │ Any                       │ Union…  │
# ├─────┼──────────────────┼─────────┼───────────────────────────┼─────────┤
# │ 1   │ Index            │ 144.5   │ 2                         │ 144.5   │
# │ 2   │ Method           │         │ Scatter-Thin_plate_spline │         │
# │ 3   │ Mode             │         │ Gridded                   │         │
# │ 4   │ Point_count      │ 24.75   │ 9                         │ 20.5    │
# │ 5   │ Median_speed     │ 67.2139 │ 23.0403                   │ 60.0445 │
# │ 6   │ Magnitude_of_MSE │ 15.5741 │ 0.123863                  │ 5.63323 │
# │ 7   │ Angle_RMS        │ 56.9173 │ 22.4358                   │ 51.6721 │
# │ 8   │ Angle_mean       │ 24.3186 │ 3.67                      │ 20.1146 │
# │ 9   │ Benchmark        │         │                           │         │
# │ 10  │ Truth_flow       │         │                           │         │
# │ 11  │ Method_flow      │         │                           │         │
# │ 12  │ Scatter_points   │         │                           │         │
# ***** Scatter-Thin_plate_spline *****
# 12×8 DataFrame. Omitted printing of 4 columns
# │ Row │ variable         │ mean    │ min                    │ median  │
# │     │ Symbol           │ Union…  │ Any                    │ Union…  │
# ├─────┼──────────────────┼─────────┼────────────────────────┼─────────┤
# │ 1   │ Index            │ 145.5   │ 3                      │ 145.5   │
# │ 2   │ Method           │         │ Scatter-Multiquadratic │         │
# │ 3   │ Mode             │         │ Gridded                │         │
# │ 4   │ Point_count      │ 24.75   │ 9                      │ 20.5    │
# │ 5   │ Median_speed     │ 21.8529 │ 9.60911                │ 21.5481 │
# │ 6   │ Magnitude_of_MSE │ 13.3377 │ 0.36952                │ 8.20141 │
# │ 7   │ Angle_RMS        │ 59.6889 │ 16.5392                │ 54.272  │
# │ 8   │ Angle_mean       │ 27.3945 │ 4.26751                │ 24.5603 │
# │ 9   │ Benchmark        │         │                        │         │
# │ 10  │ Truth_flow       │         │                        │         │
# │ 11  │ Method_flow      │         │                        │         │
# │ 12  │ Scatter_points   │         │                        │         │
# ***** Scatter-Multiquadratic *****

# %%
"""
    gen_rand_points(flow, point_count, mode; max_skew_const=4)

Generate `point_count` random indices over `flow` depending on selection `mode`.
"""
function gen_rand_points(flow, point_count, mode; max_skew_const=4)
    if mode == "Random_points"
        ret_inds = rand(CartesianIndices(flow), point_count)
    elseif mode == "Gridded"
        points_in_dim = round(Int64, sqrt(point_count))
        point_spacing = floor.(size(flow) ./ points_in_dim)

        ret_inds = Array{CartesianIndex{2}, 1}(undef, 0)
        for ind in CartesianIndices(flow)
            if all((Tuple(ind)) .% point_spacing .== 0)
                add_ind = CartesianIndex(Tuple(ind) .- floor.(Int64, point_spacing ./ 2))
                push!(ret_inds, add_ind)
            end
        end
    elseif mode == "Semigridded"
        points_in_dim = round(Int64, sqrt(point_count))
        point_spacing = floor.(size(flow) ./ points_in_dim)

        ret_inds = Array{CartesianIndex{2}, 1}(undef, 0)
        for ind in CartesianIndices(flow)
            if all((Tuple(ind)) .% point_spacing .== 0)
                skew = (rand((-floor(Int64, point_spacing[1]/max_skew_const):floor(Int64, point_spacing[1]/max_skew_const))),
                        rand((-floor(Int64, point_spacing[1]/max_skew_const):floor(Int64, point_spacing[2]/max_skew_const))))
                add_ind = CartesianIndex(Tuple(ind) .- floor.(Int64, point_spacing ./ 2) .+ skew)
                @assert add_ind in CartesianIndices(flow)

                push!(ret_inds, add_ind)
            end
        end
    end
    return ret_inds
end
# Out:
# gen_rand_points

# %%
flow = gen_tiled_flow((100, 100), 20, 40)
showflow(flow, ret="PyObject");
#plt.close()
# Out:
# Figure(PyObject <Figure size 1920x1440 with 1 Axes>)
