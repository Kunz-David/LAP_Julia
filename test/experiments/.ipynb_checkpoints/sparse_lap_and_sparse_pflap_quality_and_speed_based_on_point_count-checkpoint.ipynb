# %% [markdown]
# # `sparse_lap` and `sparse_pflap` quality and speed based on point count

# %% [markdown]
# __Goal__: See the relationship between the `sparse_lap` quality and speed based on the number of points used in the algorithm.
#
# __Data__: all `point_counts` * `spacings` * `diag_sizes`

# %%
using LAP_julia, TimerOutputs, DataFrames, TableView, JLD2, FileIO, PyPlot, BenchmarkTools, Interact
using LAP_julia: fun_on_dict_values, resize_to_diag_size
using WebIO
WebIO.install_jupyter_nbextension()
# Out:
# ┌ Info: Installing Jupyter WebIO extension...
# │   cmd = `/Users/MrTrololord/.julia/conda/3/bin/jupyter nbextension install --user /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/bundles/webio-jupyter-notebook.js`
# └ @ WebIO /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/jupyter.jl:237
# Up to date: /Users/MrTrololord/Library/Jupyter/nbextensions/webio-jupyter-notebook.js
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable <the entry point> --user
#
# ┌ Info: Enabling Jupyter WebIO extension...
# │   cmd = `/Users/MrTrololord/.julia/conda/3/bin/jupyter nbextension enable --user webio-jupyter-notebook`
# └ @ WebIO /Users/MrTrololord/.julia/packages/WebIO/2nnB1/deps/jupyter.jl:241
# Enabling notebook extension webio-jupyter-notebook...
#       - Validating: OK

# %%
# prepare new dataframe
sp_lap_point_count = DataFrame(
    index = Int[],
    diag_size = Int[],
    whs = Int[],
    timer = TimerOutput[],
    median_results = Dict{String,Float64}[],
    point_count = Int[],
    spacing = Int[],
    points_found = Float16[]
    );

# window half sizes/half sizes of filter bases, also half this number is the maximal displacement.
#window_half_sizes = [15, 30, 45
window_half_sizes = [20]
# diagonal size of the images
diag_sizes = [400, 550, 700];
# point counts
point_counts = [50, 200, 350, 500, 650, 800, 1100, 1400]
# minimal number of pixels between two points.
spacings = [5, 15, 35, 50, 60, 80, 100, 120, 140]
# number of anhir images used, these are warped by a known flow.
img_count = 5;

# arrays
errors = Array{Any}(undef, 0);

total_iterations = sum(broadcast(*, length.([window_half_sizes, diag_sizes, point_counts, spacings])...))
# Out:
# 1080

# %%
# prepare images:
imgs = Array{Image}(undef, 5);
for k in 1:img_count
    imgs[k], _ = gen_anhir(mutate=false); # here pass a kwarg: base_path="path/to/anhir/folder/"
end
# Out:
# /Users/MrTrololord/Documents/anhir/dataset/mammary-gland_2/scale-25pc/s2_61-HE_A4926-4L.jpg
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #gen_anhir#29(::Bool, ::Int64, ::typeof(gen_anhir), ::String) at data_gen.jl:10
# └ @ LAP_julia /Users/MrTrololord/Google_Drive/cvut/bakalarka/LAP_julia/src/data_gen.jl:10
# /Users/MrTrololord/Documents/anhir/dataset/mammary-gland_1/scale-25pc/s1-39-HE_A4926-4L.jpg
# sizes: (2946, 8918), (2580, 8424)
# /Users/MrTrololord/Documents/anhir/dataset/lung-lesion_3/scale-50pc/29-041-Izd2-w35-He-les3.jpg
# sizes: (6610, 8919), (6597, 8922)
# /Users/MrTrololord/Documents/anhir/dataset/gastric_3/scale-15pc/CD4.jpg
# sizes: (13367, 10458), (13193, 11056)
# /Users/MrTrololord/Documents/anhir/dataset/lung-lesion_1/scale-50pc/29-041-Izd2-w35-CD31-3-les1.jpg
# sizes: (7351, 8917), (7328, 8899)

# %%
# erase old_results
df = sp_lap_point_count;

# %% [markdown]
# ## gather data

# %%
let index = 0
    for diag_size in diag_sizes
        for whs in window_half_sizes
            for point_count in point_counts, spacing in spacings
                timer = TimerOutput("reg alg: sp lap")
                results_dicts = Array{Dict}(undef, img_count)
                inds_array = Array{Array{Any}}(undef, img_count)

                for k in 1:img_count
                    img = resize_to_diag_size(imgs[k], diag_size)
                    whs_limited = round(Int, min(whs, min(size(img)...)/4))
                    rand_flow = gen_quad_flow(size(img), whs_limited)
                    imgw = warp_img(img, real(rand_flow), imag(rand_flow))
                    try
                        # run registration function
                        _, _, timer, results_dicts[k], (_, inds_array[k]) = test_registration_alg(sparse_lap,
                            img, imgw, rand_flow, [whs_limited], Dict(:timer => timer, :point_count =>
                                point_count, :spacing => spacing), timer=timer, display=false)
                    catch e
                        println(e)
                        push!(errors, [e, img, imgw, rand_flow, whs_limited])
                        continue
                    end
                end
                # if no data gathered:
                if any(x-> 0 .== x, length.([results_dicts, inds_array]))
                    println("SKIPPED: diag_size:", diag_size, " whs: ", whs)
                    continue
                end

                median_results = fun_on_dict_values(filter_defined(results_dicts), median)
                avg_points_found = LAP_julia.mean(map(x -> length(x), filter_defined(inds_array)))

                index = index + 1
                println("at index: ", index, " (of $total_iterations) ", " diag_size: ", diag_size, " whs: ", whs)
                push!(df, Dict(:index => index,
                               :diag_size => diag_size,
                               :whs => whs,
                               :timer => timer,
                               :median_results => median_results,
                               :point_count => point_count,
                               :spacing => spacing,
                               :points_found => avg_points_found
                               ))
            end # point_count in point_counts, spacing in spacings
        end
    end
end
# Out:
# at index: 1 (of 1080)  diag_size: 400 whs: 20
# at index: 2 (of 1080)  diag_size: 400 whs: 20
# at index: 3 (of 1080)  diag_size: 400 whs: 20
# at index: 4 (of 1080)  diag_size: 400 whs: 20
# at index: 5 (of 1080)  diag_size: 400 whs: 20
# at index: 6 (of 1080)  diag_size: 400 whs: 20
# at index: 7 (of 1080)  diag_size: 400 whs: 20
# at index: 8 (of 1080)  diag_size: 400 whs: 20
# at index: 9 (of 1080)  diag_size: 400 whs: 20
# at index: 10 (of 1080)  diag_size: 400 whs: 20
# at index: 11 (of 1080)  diag_size: 400 whs: 20
# at index: 12 (of 1080)  diag_size: 400 whs: 20
# at index: 13 (of 1080)  diag_size: 400 whs: 20
# at index: 14 (of 1080)  diag_size: 400 whs: 20
# at index: 15 (of 1080)  diag_size: 400 whs: 20
# at index: 16 (of 1080)  diag_size: 400 whs: 20
# at index: 17 (of 1080)  diag_size: 400 whs: 20
# at index: 18 (of 1080)  diag_size: 400 whs: 20
# at index: 19 (of 1080)  diag_size: 400 whs: 20
# at index: 20 (of 1080)  diag_size: 400 whs: 20
# at index: 21 (of 1080)  diag_size: 400 whs: 20
# at index: 22 (of 1080)  diag_size: 400 whs: 20
# at index: 23 (of 1080)  diag_size: 400 whs: 20
# at index: 24 (of 1080)  diag_size: 400 whs: 20
# at index: 25 (of 1080)  diag_size: 400 whs: 20
# at index: 26 (of 1080)  diag_size: 400 whs: 20
# at index: 27 (of 1080)  diag_size: 400 whs: 20
# at index: 28 (of 1080)  diag_size: 400 whs: 20
# at index: 29 (of 1080)  diag_size: 400 whs: 20
# at index: 30 (of 1080)  diag_size: 400 whs: 20
# at index: 31 (of 1080)  diag_size: 400 whs: 20
# at index: 32 (of 1080)  diag_size: 400 whs: 20
# at index: 33 (of 1080)  diag_size: 400 whs: 20
# at index: 34 (of 1080)  diag_size: 400 whs: 20
# at index: 35 (of 1080)  diag_size: 400 whs: 20
# at index: 36 (of 1080)  diag_size: 400 whs: 20
# at index: 37 (of 1080)  diag_size: 400 whs: 20
# at index: 38 (of 1080)  diag_size: 400 whs: 20
# at index: 39 (of 1080)  diag_size: 400 whs: 20
# at index: 40 (of 1080)  diag_size: 400 whs: 20
# at index: 41 (of 1080)  diag_size: 400 whs: 20
# at index: 42 (of 1080)  diag_size: 400 whs: 20
# at index: 43 (of 1080)  diag_size: 400 whs: 20
# at index: 44 (of 1080)  diag_size: 400 whs: 20
# at index: 45 (of 1080)  diag_size: 400 whs: 20
# at index: 46 (of 1080)  diag_size: 400 whs: 20
# at index: 47 (of 1080)  diag_size: 400 whs: 20
# at index: 48 (of 1080)  diag_size: 400 whs: 20
# at index: 49 (of 1080)  diag_size: 400 whs: 20
# at index: 50 (of 1080)  diag_size: 400 whs: 20
# at index: 51 (of 1080)  diag_size: 400 whs: 20
# at index: 52 (of 1080)  diag_size: 400 whs: 20
# at index: 53 (of 1080)  diag_size: 400 whs: 20
# at index: 54 (of 1080)  diag_size: 400 whs: 20
# at index: 55 (of 1080)  diag_size: 400 whs: 20
# at index: 56 (of 1080)  diag_size: 400 whs: 20
# at index: 57 (of 1080)  diag_size: 400 whs: 20
# at index: 58 (of 1080)  diag_size: 400 whs: 20
# at index: 59 (of 1080)  diag_size: 400 whs: 20
# at index: 60 (of 1080)  diag_size: 400 whs: 20
# at index: 61 (of 1080)  diag_size: 400 whs: 20
# at index: 62 (of 1080)  diag_size: 400 whs: 20
# at index: 63 (of 1080)  diag_size: 400 whs: 20
# at index: 64 (of 1080)  diag_size: 400 whs: 20
# at index: 65 (of 1080)  diag_size: 400 whs: 20
# at index: 66 (of 1080)  diag_size: 400 whs: 20
# at index: 67 (of 1080)  diag_size: 400 whs: 20
# at index: 68 (of 1080)  diag_size: 400 whs: 20
# at index: 69 (of 1080)  diag_size: 400 whs: 20
# at index: 70 (of 1080)  diag_size: 400 whs: 20
# at index: 71 (of 1080)  diag_size: 400 whs: 20
# at index: 72 (of 1080)  diag_size: 400 whs: 20
# at index: 73 (of 1080)  diag_size: 550 whs: 20
# at index: 74 (of 1080)  diag_size: 550 whs: 20
# at index: 75 (of 1080)  diag_size: 550 whs: 20
# at index: 76 (of 1080)  diag_size: 550 whs: 20
# at index: 77 (of 1080)  diag_size: 550 whs: 20
# at index: 78 (of 1080)  diag_size: 550 whs: 20
# at index: 79 (of 1080)  diag_size: 550 whs: 20
# at index: 80 (of 1080)  diag_size: 550 whs: 20
# at index: 81 (of 1080)  diag_size: 550 whs: 20
# at index: 82 (of 1080)  diag_size: 550 whs: 20
# at index: 83 (of 1080)  diag_size: 550 whs: 20
# at index: 84 (of 1080)  diag_size: 550 whs: 20
# at index: 85 (of 1080)  diag_size: 550 whs: 20
# at index: 86 (of 1080)  diag_size: 550 whs: 20
# at index: 87 (of 1080)  diag_size: 550 whs: 20
# at index: 88 (of 1080)  diag_size: 550 whs: 20
# at index: 89 (of 1080)  diag_size: 550 whs: 20
# at index: 90 (of 1080)  diag_size: 550 whs: 20
# at index: 91 (of 1080)  diag_size: 550 whs: 20
# at index: 92 (of 1080)  diag_size: 550 whs: 20
# at index: 93 (of 1080)  diag_size: 550 whs: 20
# at index: 94 (of 1080)  diag_size: 550 whs: 20
# at index: 95 (of 1080)  diag_size: 550 whs: 20
# at index: 96 (of 1080)  diag_size: 550 whs: 20
# at index: 97 (of 1080)  diag_size: 550 whs: 20
# at index: 98 (of 1080)  diag_size: 550 whs: 20
# at index: 99 (of 1080)  diag_size: 550 whs: 20
# at index: 100 (of 1080)  diag_size: 550 whs: 20
# at index: 101 (of 1080)  diag_size: 550 whs: 20
# at index: 102 (of 1080)  diag_size: 550 whs: 20
# at index: 103 (of 1080)  diag_size: 550 whs: 20
# at index: 104 (of 1080)  diag_size: 550 whs: 20
# at index: 105 (of 1080)  diag_size: 550 whs: 20
# at index: 106 (of 1080)  diag_size: 550 whs: 20
# at index: 107 (of 1080)  diag_size: 550 whs: 20
# at index: 108 (of 1080)  diag_size: 550 whs: 20
# at index: 109 (of 1080)  diag_size: 550 whs: 20
# at index: 110 (of 1080)  diag_size: 550 whs: 20
# at index: 111 (of 1080)  diag_size: 550 whs: 20
# at index: 112 (of 1080)  diag_size: 550 whs: 20
# at index: 113 (of 1080)  diag_size: 550 whs: 20
# at index: 114 (of 1080)  diag_size: 550 whs: 20
# at index: 115 (of 1080)  diag_size: 550 whs: 20
# at index: 116 (of 1080)  diag_size: 550 whs: 20
# at index: 117 (of 1080)  diag_size: 550 whs: 20
# at index: 118 (of 1080)  diag_size: 550 whs: 20
# at index: 119 (of 1080)  diag_size: 550 whs: 20
# at index: 120 (of 1080)  diag_size: 550 whs: 20
# at index: 121 (of 1080)  diag_size: 550 whs: 20
# at index: 122 (of 1080)  diag_size: 550 whs: 20
# at index: 123 (of 1080)  diag_size: 550 whs: 20
# at index: 124 (of 1080)  diag_size: 550 whs: 20
# at index: 125 (of 1080)  diag_size: 550 whs: 20
# at index: 126 (of 1080)  diag_size: 550 whs: 20
# at index: 127 (of 1080)  diag_size: 550 whs: 20
# at index: 128 (of 1080)  diag_size: 550 whs: 20
# at index: 129 (of 1080)  diag_size: 550 whs: 20
# at index: 130 (of 1080)  diag_size: 550 whs: 20
# at index: 131 (of 1080)  diag_size: 550 whs: 20
# at index: 132 (of 1080)  diag_size: 550 whs: 20
# at index: 133 (of 1080)  diag_size: 550 whs: 20
# at index: 134 (of 1080)  diag_size: 550 whs: 20
# at index: 135 (of 1080)  diag_size: 550 whs: 20
# at index: 136 (of 1080)  diag_size: 550 whs: 20
# at index: 137 (of 1080)  diag_size: 550 whs: 20
# at index: 138 (of 1080)  diag_size: 550 whs: 20
# at index: 139 (of 1080)  diag_size: 550 whs: 20
# at index: 140 (of 1080)  diag_size: 550 whs: 20
# at index: 141 (of 1080)  diag_size: 550 whs: 20
# at index: 142 (of 1080)  diag_size: 550 whs: 20
# at index: 143 (of 1080)  diag_size: 550 whs: 20
# at index: 144 (of 1080)  diag_size: 550 whs: 20
# at index: 145 (of 1080)  diag_size: 700 whs: 20
# at index: 146 (of 1080)  diag_size: 700 whs: 20
# at index: 147 (of 1080)  diag_size: 700 whs: 20
# at index: 148 (of 1080)  diag_size: 700 whs: 20
# at index: 149 (of 1080)  diag_size: 700 whs: 20
# at index: 150 (of 1080)  diag_size: 700 whs: 20
# at index: 151 (of 1080)  diag_size: 700 whs: 20
# at index: 152 (of 1080)  diag_size: 700 whs: 20
# at index: 153 (of 1080)  diag_size: 700 whs: 20
# at index: 154 (of 1080)  diag_size: 700 whs: 20
# at index: 155 (of 1080)  diag_size: 700 whs: 20
# at index: 156 (of 1080)  diag_size: 700 whs: 20
# at index: 157 (of 1080)  diag_size: 700 whs: 20
# at index: 158 (of 1080)  diag_size: 700 whs: 20
# at index: 159 (of 1080)  diag_size: 700 whs: 20
# at index: 160 (of 1080)  diag_size: 700 whs: 20
# at index: 161 (of 1080)  diag_size: 700 whs: 20
# at index: 162 (of 1080)  diag_size: 700 whs: 20
# at index: 163 (of 1080)  diag_size: 700 whs: 20
# at index: 164 (of 1080)  diag_size: 700 whs: 20
# at index: 165 (of 1080)  diag_size: 700 whs: 20
# at index: 166 (of 1080)  diag_size: 700 whs: 20
# at index: 167 (of 1080)  diag_size: 700 whs: 20
# at index: 168 (of 1080)  diag_size: 700 whs: 20
# at index: 169 (of 1080)  diag_size: 700 whs: 20
# at index: 170 (of 1080)  diag_size: 700 whs: 20
# at index: 171 (of 1080)  diag_size: 700 whs: 20
# at index: 172 (of 1080)  diag_size: 700 whs: 20
# at index: 173 (of 1080)  diag_size: 700 whs: 20
# at index: 174 (of 1080)  diag_size: 700 whs: 20
# at index: 175 (of 1080)  diag_size: 700 whs: 20
# at index: 176 (of 1080)  diag_size: 700 whs: 20
# at index: 177 (of 1080)  diag_size: 700 whs: 20
# at index: 178 (of 1080)  diag_size: 700 whs: 20
# at index: 179 (of 1080)  diag_size: 700 whs: 20
# at index: 180 (of 1080)  diag_size: 700 whs: 20
# at index: 181 (of 1080)  diag_size: 700 whs: 20
# at index: 182 (of 1080)  diag_size: 700 whs: 20
# at index: 183 (of 1080)  diag_size: 700 whs: 20
# at index: 184 (of 1080)  diag_size: 700 whs: 20
# at index: 185 (of 1080)  diag_size: 700 whs: 20
# at index: 186 (of 1080)  diag_size: 700 whs: 20
# at index: 187 (of 1080)  diag_size: 700 whs: 20
# at index: 188 (of 1080)  diag_size: 700 whs: 20
# at index: 189 (of 1080)  diag_size: 700 whs: 20
# at index: 190 (of 1080)  diag_size: 700 whs: 20
# at index: 191 (of 1080)  diag_size: 700 whs: 20
# at index: 192 (of 1080)  diag_size: 700 whs: 20
# at index: 193 (of 1080)  diag_size: 700 whs: 20
# at index: 194 (of 1080)  diag_size: 700 whs: 20
# at index: 195 (of 1080)  diag_size: 700 whs: 20
# at index: 196 (of 1080)  diag_size: 700 whs: 20
# at index: 197 (of 1080)  diag_size: 700 whs: 20
# at index: 198 (of 1080)  diag_size: 700 whs: 20
# at index: 199 (of 1080)  diag_size: 700 whs: 20
# at index: 200 (of 1080)  diag_size: 700 whs: 20
# at index: 201 (of 1080)  diag_size: 700 whs: 20
# at index: 202 (of 1080)  diag_size: 700 whs: 20
# at index: 203 (of 1080)  diag_size: 700 whs: 20
# at index: 204 (of 1080)  diag_size: 700 whs: 20
# at index: 205 (of 1080)  diag_size: 700 whs: 20
# at index: 206 (of 1080)  diag_size: 700 whs: 20
# at index: 207 (of 1080)  diag_size: 700 whs: 20
# at index: 208 (of 1080)  diag_size: 700 whs: 20
# at index: 209 (of 1080)  diag_size: 700 whs: 20
# at index: 210 (of 1080)  diag_size: 700 whs: 20
# at index: 211 (of 1080)  diag_size: 700 whs: 20
# at index: 212 (of 1080)  diag_size: 700 whs: 20
# at index: 213 (of 1080)  diag_size: 700 whs: 20
# at index: 214 (of 1080)  diag_size: 700 whs: 20
# at index: 215 (of 1080)  diag_size: 700 whs: 20
# at index: 216 (of 1080)  diag_size: 700 whs: 20

# %% [markdown]
# ## Visualise results

# %%
timers = df[((df.diag_size .== 400) .& (df.spacing .== 5)), :][:, :timer]
# Out:
# 8-element Array{TimerOutput,1}:
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16357s / 0.01%            632GiB / 0.03%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.52s   100%   304ms    174MiB  100%   34.8MiB
#    sparse lap               5    1.29s  85.2%   259ms    115MiB  66.1%  23.0MiB
#      multi mat div          5    582ms  38.3%   116ms   16.9MiB  9.73%  3.39MiB
#      filtering              5    566ms  37.3%   113ms   60.2MiB  34.6%  12.0MiB
#      prepare A and b        5   68.5ms  4.51%  13.7ms   30.1MiB  17.3%  6.02MiB
#        window sum p...     15   43.0ms  2.83%  2.87ms   18.1MiB  10.4%  1.20MiB
#        window sum p...     10   25.4ms  1.67%  2.54ms   12.0MiB  6.91%  1.20MiB
#      calculate flow         5   14.5μs  0.00%  2.90μs   9.69KiB  0.01%  1.94KiB
#    generate source_reg      5   93.4ms  6.15%  18.7ms   30.1MiB  17.3%  6.01MiB
#    find edge points         5   91.3ms  6.01%  18.3ms   20.9MiB  12.0%  4.18MiB
#    interpolate flow         5   7.57ms  0.50%  1.51ms   7.99MiB  4.59%  1.60MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16315s / 0.00%            608GiB / 0.04%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    726ms   100%   145ms    225MiB  100%   45.1MiB
#    sparse lap               5    557ms  76.7%   111ms    166MiB  73.7%  33.2MiB
#      multi mat div          5    318ms  43.8%  63.5ms   67.8MiB  30.1%  13.6MiB
#      filtering              5    206ms  28.4%  41.2ms   60.2MiB  26.7%  12.0MiB
#      prepare A and b        5   28.3ms  3.89%  5.66ms   30.1MiB  13.4%  6.02MiB
#        window sum p...     15   17.2ms  2.36%  1.14ms   18.1MiB  8.02%  1.20MiB
#        window sum p...     10   11.1ms  1.52%  1.11ms   12.0MiB  5.34%  1.20MiB
#      calculate flow         5   31.8μs  0.00%  6.35μs   33.4KiB  0.01%  6.69KiB
#    generate source_reg      5   97.9ms  13.5%  19.6ms   30.1MiB  13.3%  6.01MiB
#    find edge points         5   58.8ms  8.09%  11.8ms   21.0MiB  9.30%  4.19MiB
#    interpolate flow         5   11.0ms  1.52%  2.20ms   8.24MiB  3.66%  1.65MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16261s / 0.01%            584GiB / 0.05%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    2.02s   100%   404ms    277MiB  100%   55.3MiB
#    sparse lap               5    1.55s  76.5%   309ms    217MiB  78.5%  43.4MiB
#      multi mat div          5    795ms  39.4%   159ms    119MiB  42.9%  23.7MiB
#      filtering              5    644ms  31.9%   129ms   60.2MiB  21.8%  12.0MiB
#      prepare A and b        5   98.0ms  4.85%  19.6ms   30.1MiB  10.9%  6.02MiB
#        window sum p...     15   56.4ms  2.79%  3.76ms   18.1MiB  6.54%  1.21MiB
#        window sum p...     10   41.5ms  2.05%  4.15ms   12.0MiB  4.35%  1.20MiB
#      calculate flow         5   3.46ms  0.17%   692μs   57.2KiB  0.02%  11.4KiB
#    find edge points         5    281ms  13.9%  56.1ms   21.0MiB  7.59%  4.20MiB
#    generate source_reg      5    160ms  7.91%  32.0ms   30.1MiB  10.9%  6.01MiB
#    interpolate flow         5   29.1ms  1.44%  5.82ms   8.48MiB  3.07%  1.70MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16196s / 0.01%            560GiB / 0.06%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.78s   100%   355ms    328MiB  100%   65.6MiB
#    sparse lap               5    1.48s  83.2%   296ms    268MiB  81.7%  53.6MiB
#      multi mat div          5    1.05s  59.3%   211ms    169MiB  51.7%  33.9MiB
#      filtering              5    326ms  18.4%  65.2ms   60.2MiB  18.4%  12.0MiB
#      prepare A and b        5   83.6ms  4.71%  16.7ms   30.1MiB  9.20%  6.03MiB
#        window sum p...     15   55.2ms  3.11%  3.68ms   18.1MiB  5.52%  1.21MiB
#        window sum p...     10   28.3ms  1.59%  2.83ms   12.0MiB  3.67%  1.20MiB
#      calculate flow         5   2.46ms  0.14%   491μs   80.3KiB  0.02%  16.1KiB
#    find edge points         5    148ms  8.31%  29.5ms   21.0MiB  6.41%  4.20MiB
#    generate source_reg      5   96.7ms  5.44%  19.3ms   30.1MiB  9.17%  6.01MiB
#    interpolate flow         5   51.5ms  2.90%  10.3ms   8.72MiB  2.66%  1.74MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16141s / 0.01%            536GiB / 0.07%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.25s   100%   250ms    379MiB  100%   75.8MiB
#    sparse lap               5    939ms  75.1%   188ms    319MiB  84.1%  63.8MiB
#      multi mat div          5    553ms  44.2%   111ms    220MiB  58.1%  44.0MiB
#      filtering              5    332ms  26.6%  66.4ms   60.2MiB  15.9%  12.0MiB
#      prepare A and b        5   43.2ms  3.46%  8.65ms   30.2MiB  7.96%  6.03MiB
#        window sum p...     15   29.9ms  2.39%  1.99ms   18.1MiB  4.78%  1.21MiB
#        window sum p...     10   13.2ms  1.06%  1.32ms   12.0MiB  3.17%  1.20MiB
#      calculate flow         5   1.31ms  0.10%   261μs    104KiB  0.03%  20.8KiB
#    find edge points         5    170ms  13.6%  34.0ms   21.0MiB  5.55%  4.21MiB
#    generate source_reg      5   81.5ms  6.52%  16.3ms   30.1MiB  7.93%  6.01MiB
#    interpolate flow         5   57.9ms  4.63%  11.6ms   8.95MiB  2.36%  1.79MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16080s / 0.01%            511GiB / 0.08%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.35s   100%   270ms    428MiB  100%   85.6MiB
#    sparse lap               5    1.07s  79.1%   213ms    368MiB  85.9%  73.5MiB
#      multi mat div          5    620ms  45.9%   124ms    269MiB  62.8%  53.8MiB
#      filtering              5    350ms  26.0%  70.1ms   60.2MiB  14.1%  12.0MiB
#      prepare A and b        5   77.2ms  5.72%  15.4ms   30.2MiB  7.05%  6.03MiB
#        window sum p...     15   44.2ms  3.28%  2.95ms   18.1MiB  4.24%  1.21MiB
#        window sum p...     10   32.9ms  2.44%  3.29ms   12.0MiB  2.81%  1.20MiB
#      calculate flow         5   5.63ms  0.42%  1.13ms    126KiB  0.03%  25.3KiB
#    find edge points         5    169ms  12.5%  33.9ms   21.1MiB  4.92%  4.21MiB
#    generate source_reg      5   72.5ms  5.37%  14.5ms   30.1MiB  7.02%  6.01MiB
#    interpolate flow         5   38.8ms  2.88%  7.77ms   9.16MiB  2.14%  1.83MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           16031s / 0.01%            487GiB / 0.10%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.29s   100%   258ms    495MiB  100%   99.0MiB
#    sparse lap               5    910ms  70.5%   182ms    434MiB  87.7%  86.9MiB
#      multi mat div          5    499ms  38.7%   100ms    335MiB  67.7%  67.1MiB
#      filtering              5    320ms  24.8%  63.9ms   60.2MiB  12.2%  12.0MiB
#      prepare A and b        5   66.1ms  5.12%  13.2ms   30.2MiB  6.10%  6.04MiB
#        window sum p...     15   47.3ms  3.67%  3.16ms   18.2MiB  3.67%  1.21MiB
#        window sum p...     10   18.7ms  1.45%  1.87ms   12.0MiB  2.43%  1.20MiB
#      calculate flow         5   11.2ms  0.87%  2.24ms    157KiB  0.03%  31.3KiB
#    find edge points         5    275ms  21.3%  55.0ms   21.1MiB  4.26%  4.22MiB
#    generate source_reg      5   73.8ms  5.72%  14.8ms   30.1MiB  6.07%  6.01MiB
#    interpolate flow         5   28.7ms  2.23%  5.74ms   9.49MiB  1.92%  1.90MiB
#  ──────────────────────────────────────────────────────────────────────────────
#   ──────────────────────────────────────────────────────────────────────────────
#                                        Time                   Allocations
#                                ──────────────────────   ───────────────────────
#        Tot / % measured:           15983s / 0.01%            463GiB / 0.12%
#
#  Section               ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────────
#  reg alg: sp lap            5    1.98s   100%   396ms    552MiB  100%    110MiB
#    sparse lap               5    1.60s  80.8%   320ms    491MiB  88.9%  98.2MiB
#      multi mat div          5    896ms  45.3%   179ms    392MiB  71.0%  78.4MiB
#      filtering              5    612ms  30.9%   122ms   60.2MiB  10.9%  12.0MiB
#      prepare A and b        5   72.3ms  3.65%  14.5ms   30.2MiB  5.47%  6.04MiB
#        window sum p...     15   42.1ms  2.13%  2.81ms   18.2MiB  3.29%  1.21MiB
#        window sum p...     10   30.0ms  1.52%  3.00ms   12.0MiB  2.18%  1.20MiB
#      calculate flow         5   12.1ms  0.61%  2.43ms    183KiB  0.03%  36.6KiB
#    find edge points         5    274ms  13.8%  54.8ms   21.1MiB  3.83%  4.23MiB
#    generate source_reg      5   81.9ms  4.14%  16.4ms   30.1MiB  5.44%  6.01MiB
#    interpolate flow         5   19.2ms  0.97%  3.84ms   9.77MiB  1.77%  1.95MiB
#  ──────────────────────────────────────────────────────────────────────────────

# %%
@manipulate for k in slider(1:length(spacings), value=1, label="spacing")
    spacing = spacings[k]
    fig, axs = subplots(length(diag_sizes), sharex=true, figsize=(10,10))
    for (diag_size, ax) in zip(diag_sizes, axs)
        ax.set_title("Diagonal Size: " * string(diag_size))

        local_df = df[((df.diag_size .== diag_size) .& (df.spacing .== spacing)), :]

        # get times
        timers = local_df[:, :timer]
        avg_times = map(x -> get_avg_time(get_timer(x, sections)), timers)

        # get flow mae
        median_dicts = local_df[:, :median_results]
        median_flow_mae = map(dict -> dict["flow_mae"], median_dicts)

        # xscale("log")
        # yscale("log")
        subplots_adjust(top=1.5)
        ax.plot(point_counts, avg_times)
        ax.plot(median_flow_mae, avg_times)
        xlabel("point count")
        ax.set_ylabel("time [s] & mae [pixel]")
    end
    gcf()
end
# Out:
# UndefVarError: to_value not defined
#
# Stacktrace:
#  [1] getproperty at ./Base.jl:13 [inlined]
#  [2] #slider#74(::Int64, ::Base.Iterators.Pairs{Symbol,String,Tuple{Symbol},NamedTuple{(:label,),Tuple{String}}}, ::typeof(slider), ::Interact.Bulma, ::Array{Int64,1}, ::Array{String,1}) at /Users/MrTrololord/.julia/packages/InteractBase/sOe2Z/src/slider.jl:20
#  [3] (::Widgets.var"#kw##slider")(::NamedTuple{(:value, :label),Tuple{Int64,String}}, ::typeof(slider), ::Interact.Bulma, ::Array{Int64,1}, ::Array{String,1}) at ./none:0
#  [4] (::Widgets.var"#kw##slider")(::NamedTuple{(:value, :label),Tuple{Int64,String}}, ::typeof(slider), ::Interact.Bulma, ::Array{Int64,1}) at ./simdloop.jl:0
#  [5] #slider#56(::Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol},NamedTuple{(:value, :label),Tuple{Int64,String}}}, ::typeof(slider), ::Array{Int64,1}) at /Users/MrTrololord/.julia/packages/Widgets/451tD/src/defaults.jl:10
#  [6] (::Widgets.var"#kw##slider")(::NamedTuple{(:value, :label),Tuple{Int64,String}}, ::typeof(slider), ::Array{Int64,1}) at ./none:0
#  [7] top-level scope at /Users/MrTrololord/.julia/packages/Widgets/451tD/src/manipulate.jl:91
#  [8] top-level scope at In[32]:1

# %% [markdown]
# ### helper functions

# %%
defined_perms(arraylike) = filter(k -> isassigned(arraylike, k), 1:length(arraylike))
filter_defined(arraylike) = arraylike[defined_perms(arraylike)]
# Out:
# filter_defined (generic function with 1 method)
