# %% [markdown]
# # Correlation between single lap residuals and estimation errors

# %% [markdown]
# Goal of this experiment is to find out whether there is a correlation between the residuals of the local all pass minimization and the error in the estimated flow at the corresposting location.

# %%
using LAP_julia, Images, ImageDistances, TimerOutputs, StatsBase
import LAP_julia: vec_len, sparse_lap, single_lap_at_points
using ImageFiltering: Fill, KernelFactors.gaussian, centered, kernelfactors, imfilter!, padarray, Pad
using LinearAlgebra: qr
using LAP_julia: window_sum3_at_inds!, multi_mat_div_qr, addpoints, to_lin_index

# %% [markdown]
# # gather data

# %%
iterations = 1000

errors = []
residuals_arr = []

for k in 1:iterations
    
    img, imgw, flow = gen_init()
    
    timer=TimerOutput("sparse lap");
    flow_est, source_reg, timer, results, (residuals, estim_at_inds, inds) = test_registration_alg(sparse_lap, img, imgw, flow, [25, (51,51)], Dict(:timer => timer), timer=timer, display=false)
    
    push!(errors, vec_len.((map(ind -> flow[ind], inds) .- estim_at_inds)))
    push!(residuals_arr, residuals)
    println(k)
end
# Out:
# !local version of sparse_lap! !local version of single_lap_at_points! 1
# !local version of sparse_lap! !local version of single_lap_at_points! 2
# !local version of sparse_lap! !local version of single_lap_at_points! 3
# !local version of sparse_lap! !local version of single_lap_at_points! 4
# !local version of sparse_lap! !local version of single_lap_at_points! 5
# !local version of sparse_lap! !local version of single_lap_at_points! 6
# !local version of sparse_lap! !local version of single_lap_at_points! 7
# !local version of sparse_lap! !local version of single_lap_at_points! 8
# !local version of sparse_lap! !local version of single_lap_at_points! 9
# !local version of sparse_lap! !local version of single_lap_at_points! 10
# !local version of sparse_lap! !local version of single_lap_at_points! 11
# !local version of sparse_lap! !local version of single_lap_at_points! 12
# !local version of sparse_lap! !local version of single_lap_at_points! 13
# !local version of sparse_lap! !local version of single_lap_at_points! 14
# !local version of sparse_lap! !local version of single_lap_at_points! 15
# !local version of sparse_lap! !local version of single_lap_at_points! 16
# !local version of sparse_lap! !local version of single_lap_at_points! 17
# !local version of sparse_lap! !local version of single_lap_at_points! 18
# !local version of sparse_lap! !local version of single_lap_at_points! 19
# !local version of sparse_lap! !local version of single_lap_at_points! 20
# !local version of sparse_lap! !local version of single_lap_at_points! 21
# !local version of sparse_lap! !local version of single_lap_at_points! 22
# !local version of sparse_lap! !local version of single_lap_at_points! 23
# !local version of sparse_lap! !local version of single_lap_at_points! 24
# !local version of sparse_lap! !local version of single_lap_at_points! 25
# !local version of sparse_lap! !local version of single_lap_at_points! 26
# !local version of sparse_lap! !local version of single_lap_at_points! 27
# !local version of sparse_lap! !local version of single_lap_at_points! 28
# !local version of sparse_lap! !local version of single_lap_at_points! 29
# !local version of sparse_lap! !local version of single_lap_at_points! 30
# !local version of sparse_lap! !local version of single_lap_at_points! 31
# !local version of sparse_lap! !local version of single_lap_at_points! 32
# !local version of sparse_lap! !local version of single_lap_at_points! 33
# !local version of sparse_lap! !local version of single_lap_at_points! 34
# !local version of sparse_lap! !local version of single_lap_at_points! 35
# !local version of sparse_lap! !local version of single_lap_at_points! 36
# !local version of sparse_lap! !local version of single_lap_at_points! 37
# !local version of sparse_lap! !local version of single_lap_at_points! 38
# !local version of sparse_lap! !local version of single_lap_at_points! 39
# !local version of sparse_lap! !local version of single_lap_at_points! 40
# !local version of sparse_lap! !local version of single_lap_at_points! 41
# !local version of sparse_lap! !local version of single_lap_at_points! 42
# !local version of sparse_lap! !local version of single_lap_at_points! 43
# !local version of sparse_lap! !local version of single_lap_at_points! 44
# !local version of sparse_lap! !local version of single_lap_at_points! 45
# !local version of sparse_lap! !local version of single_lap_at_points! 46
# !local version of sparse_lap! !local version of single_lap_at_points! 47
# !local version of sparse_lap! !local version of single_lap_at_points! 48
# !local version of sparse_lap! !local version of single_lap_at_points! 49
# !local version of sparse_lap! !local version of single_lap_at_points! 50
# !local version of sparse_lap! !local version of single_lap_at_points! 51
# !local version of sparse_lap! !local version of single_lap_at_points! 52
# !local version of sparse_lap! !local version of single_lap_at_points! 53
# !local version of sparse_lap! !local version of single_lap_at_points! 54
# !local version of sparse_lap! !local version of single_lap_at_points! 55
# !local version of sparse_lap! !local version of single_lap_at_points! 56
# !local version of sparse_lap! !local version of single_lap_at_points! 57
# !local version of sparse_lap! !local version of single_lap_at_points! 58
# !local version of sparse_lap! !local version of single_lap_at_points! 59
# !local version of sparse_lap! !local version of single_lap_at_points! 60
# !local version of sparse_lap! !local version of single_lap_at_points! 61
# !local version of sparse_lap! !local version of single_lap_at_points! 62
# !local version of sparse_lap! !local version of single_lap_at_points! 63
# !local version of sparse_lap! !local version of single_lap_at_points! 64
# !local version of sparse_lap! !local version of single_lap_at_points! 65
# !local version of sparse_lap! !local version of single_lap_at_points! 66
# !local version of sparse_lap! !local version of single_lap_at_points! 67
# !local version of sparse_lap! !local version of single_lap_at_points! 68
# !local version of sparse_lap! !local version of single_lap_at_points! 69
# !local version of sparse_lap! !local version of single_lap_at_points! 70
# !local version of sparse_lap! !local version of single_lap_at_points! 71
# !local version of sparse_lap! !local version of single_lap_at_points! 72
# !local version of sparse_lap! !local version of single_lap_at_points! 73
# !local version of sparse_lap! !local version of single_lap_at_points! 74
# !local version of sparse_lap! !local version of single_lap_at_points! 75
# !local version of sparse_lap! !local version of single_lap_at_points! 76
# !local version of sparse_lap! !local version of single_lap_at_points! 77
# !local version of sparse_lap! !local version of single_lap_at_points! 78
# !local version of sparse_lap! !local version of single_lap_at_points! 79
# !local version of sparse_lap! !local version of single_lap_at_points! 80
# !local version of sparse_lap! !local version of single_lap_at_points! 81
# !local version of sparse_lap! !local version of single_lap_at_points! 82
# !local version of sparse_lap! !local version of single_lap_at_points! 83
# !local version of sparse_lap! !local version of single_lap_at_points! 84
# !local version of sparse_lap! !local version of single_lap_at_points! 85
# !local version of sparse_lap! !local version of single_lap_at_points! 86
# !local version of sparse_lap! !local version of single_lap_at_points! 87
# !local version of sparse_lap! !local version of single_lap_at_points! 88
# !local version of sparse_lap! !local version of single_lap_at_points! 89
# !local version of sparse_lap! !local version of single_lap_at_points! 90
# !local version of sparse_lap! !local version of single_lap_at_points! 91
# !local version of sparse_lap! !local version of single_lap_at_points! 92
# !local version of sparse_lap! !local version of single_lap_at_points! 93
# !local version of sparse_lap! !local version of single_lap_at_points! 94
# !local version of sparse_lap! !local version of single_lap_at_points! 95
# !local version of sparse_lap! !local version of single_lap_at_points! 96
# !local version of sparse_lap! !local version of single_lap_at_points! 97
# !local version of sparse_lap! !local version of single_lap_at_points! 98
# !local version of sparse_lap! !local version of single_lap_at_points! 99
# !local version of sparse_lap! !local version of single_lap_at_points! 100
# !local version of sparse_lap! !local version of single_lap_at_points! 101
# !local version of sparse_lap! !local version of single_lap_at_points! 102
# !local version of sparse_lap! !local version of single_lap_at_points! 103
# !local version of sparse_lap! !local version of single_lap_at_points! 104
# !local version of sparse_lap! !local version of single_lap_at_points! 105
# !local version of sparse_lap! !local version of single_lap_at_points! 106
# !local version of sparse_lap! !local version of single_lap_at_points! 107
# !local version of sparse_lap! !local version of single_lap_at_points! 108
# !local version of sparse_lap! !local version of single_lap_at_points! 109
# !local version of sparse_lap! !local version of single_lap_at_points! 110
# !local version of sparse_lap! !local version of single_lap_at_points! 111
# !local version of sparse_lap! !local version of single_lap_at_points! 112
# !local version of sparse_lap! !local version of single_lap_at_points! 113
# !local version of sparse_lap! !local version of single_lap_at_points! 114
# !local version of sparse_lap! !local version of single_lap_at_points! 115
# !local version of sparse_lap! !local version of single_lap_at_points! 116
# !local version of sparse_lap! !local version of single_lap_at_points! 117
# !local version of sparse_lap! !local version of single_lap_at_points! 118
# !local version of sparse_lap! !local version of single_lap_at_points! 119
# !local version of sparse_lap! !local version of single_lap_at_points! 120
# !local version of sparse_lap! !local version of single_lap_at_points! 121
# !local version of sparse_lap! !local version of single_lap_at_points! 122
# !local version of sparse_lap! !local version of single_lap_at_points! 123
# !local version of sparse_lap! !local version of single_lap_at_points! 124
# !local version of sparse_lap! !local version of single_lap_at_points! 125
# !local version of sparse_lap! !local version of single_lap_at_points! 126
# !local version of sparse_lap! !local version of single_lap_at_points! 127
# !local version of sparse_lap! !local version of single_lap_at_points! 128
# !local version of sparse_lap! !local version of single_lap_at_points! 129
# !local version of sparse_lap! !local version of single_lap_at_points! 130
# !local version of sparse_lap! !local version of single_lap_at_points! 131
# !local version of sparse_lap! !local version of single_lap_at_points! 132
# !local version of sparse_lap! !local version of single_lap_at_points! 133
# !local version of sparse_lap! !local version of single_lap_at_points! 134
# !local version of sparse_lap! !local version of single_lap_at_points! 135
# !local version of sparse_lap! !local version of single_lap_at_points! 136
# !local version of sparse_lap! !local version of single_lap_at_points! 137
# !local version of sparse_lap! !local version of single_lap_at_points! 138
# !local version of sparse_lap! !local version of single_lap_at_points! 139
# !local version of sparse_lap! !local version of single_lap_at_points! 140
# !local version of sparse_lap! !local version of single_lap_at_points! 141
# !local version of sparse_lap! !local version of single_lap_at_points! 142
# !local version of sparse_lap! !local version of single_lap_at_points! 143
# !local version of sparse_lap! !local version of single_lap_at_points! 144
# !local version of sparse_lap! !local version of single_lap_at_points! 145
# !local version of sparse_lap! !local version of single_lap_at_points! 146
# !local version of sparse_lap! !local version of single_lap_at_points! 147
# !local version of sparse_lap! !local version of single_lap_at_points! 148
# !local version of sparse_lap! !local version of single_lap_at_points! 149
# !local version of sparse_lap! !local version of single_lap_at_points! 150
# !local version of sparse_lap! !local version of single_lap_at_points! 151
# !local version of sparse_lap! !local version of single_lap_at_points! 152
# !local version of sparse_lap! !local version of single_lap_at_points! 153
# !local version of sparse_lap! !local version of single_lap_at_points! 154
# !local version of sparse_lap! !local version of single_lap_at_points! 155
# !local version of sparse_lap! !local version of single_lap_at_points! 156
# !local version of sparse_lap! !local version of single_lap_at_points! 157
# !local version of sparse_lap! !local version of single_lap_at_points! 158
# !local version of sparse_lap! !local version of single_lap_at_points! 159
# !local version of sparse_lap! !local version of single_lap_at_points! 160
# !local version of sparse_lap! !local version of single_lap_at_points! 161
# !local version of sparse_lap! !local version of single_lap_at_points! 162
# !local version of sparse_lap! !local version of single_lap_at_points! 163
# !local version of sparse_lap! !local version of single_lap_at_points! 164
# !local version of sparse_lap! !local version of single_lap_at_points! 165
# !local version of sparse_lap! !local version of single_lap_at_points! 166
# !local version of sparse_lap! !local version of single_lap_at_points! 167
# !local version of sparse_lap! !local version of single_lap_at_points! 168
# !local version of sparse_lap! !local version of single_lap_at_points! 169
# !local version of sparse_lap! !local version of single_lap_at_points! 170
# !local version of sparse_lap! !local version of single_lap_at_points! 171
# !local version of sparse_lap! !local version of single_lap_at_points! 172
# !local version of sparse_lap! !local version of single_lap_at_points! 173
# !local version of sparse_lap! !local version of single_lap_at_points! 174
# !local version of sparse_lap! !local version of single_lap_at_points! 175
# !local version of sparse_lap! !local version of single_lap_at_points! 176
# !local version of sparse_lap! !local version of single_lap_at_points! 177
# !local version of sparse_lap! !local version of single_lap_at_points! 178
# !local version of sparse_lap! !local version of single_lap_at_points! 179
# !local version of sparse_lap! !local version of single_lap_at_points! 180
# !local version of sparse_lap! !local version of single_lap_at_points! 181
# !local version of sparse_lap! !local version of single_lap_at_points! 182
# !local version of sparse_lap! !local version of single_lap_at_points! 183
# !local version of sparse_lap! !local version of single_lap_at_points! 184
# !local version of sparse_lap! !local version of single_lap_at_points! 185
# !local version of sparse_lap! !local version of single_lap_at_points! 186
# !local version of sparse_lap! !local version of single_lap_at_points! 187
# !local version of sparse_lap! !local version of single_lap_at_points! 188
# !local version of sparse_lap! !local version of single_lap_at_points! 189
# !local version of sparse_lap! !local version of single_lap_at_points! 190
# !local version of sparse_lap! !local version of single_lap_at_points! 191
# !local version of sparse_lap! !local version of single_lap_at_points! 192
# !local version of sparse_lap! !local version of single_lap_at_points! 193
# !local version of sparse_lap! !local version of single_lap_at_points! 194
# !local version of sparse_lap! !local version of single_lap_at_points! 195
# !local version of sparse_lap! !local version of single_lap_at_points! 196
# !local version of sparse_lap! !local version of single_lap_at_points! 197
# !local version of sparse_lap! !local version of single_lap_at_points! 198
# !local version of sparse_lap! !local version of single_lap_at_points! 199
# !local version of sparse_lap! !local version of single_lap_at_points! 200
# !local version of sparse_lap! !local version of single_lap_at_points! 201
# !local version of sparse_lap! !local version of single_lap_at_points! 202
# !local version of sparse_lap! !local version of single_lap_at_points! 203
# !local version of sparse_lap! !local version of single_lap_at_points! 204
# !local version of sparse_lap! !local version of single_lap_at_points! 205
# !local version of sparse_lap! !local version of single_lap_at_points! 206
# !local version of sparse_lap! !local version of single_lap_at_points! 207
# !local version of sparse_lap! !local version of single_lap_at_points! 208
# !local version of sparse_lap! !local version of single_lap_at_points! 209
# !local version of sparse_lap! !local version of single_lap_at_points! 210
# !local version of sparse_lap! !local version of single_lap_at_points! 211
# !local version of sparse_lap! !local version of single_lap_at_points! 212
# !local version of sparse_lap! !local version of single_lap_at_points! 213
# !local version of sparse_lap! !local version of single_lap_at_points! 214
# !local version of sparse_lap! !local version of single_lap_at_points! 215
# !local version of sparse_lap! !local version of single_lap_at_points! 216
# !local version of sparse_lap! !local version of single_lap_at_points! 217
# !local version of sparse_lap! !local version of single_lap_at_points! 218
# !local version of sparse_lap! !local version of single_lap_at_points! 219
# !local version of sparse_lap! !local version of single_lap_at_points! 220
# !local version of sparse_lap! !local version of single_lap_at_points! 221
# !local version of sparse_lap! !local version of single_lap_at_points! 222
# !local version of sparse_lap! !local version of single_lap_at_points! 223
# !local version of sparse_lap! !local version of single_lap_at_points! 224
# !local version of sparse_lap! !local version of single_lap_at_points! 225
# !local version of sparse_lap! !local version of single_lap_at_points! 226
# !local version of sparse_lap! !local version of single_lap_at_points! 227
# !local version of sparse_lap! !local version of single_lap_at_points! 228
# !local version of sparse_lap! !local version of single_lap_at_points! 229
# !local version of sparse_lap! !local version of single_lap_at_points! 230
# !local version of sparse_lap! !local version of single_lap_at_points! 231
# !local version of sparse_lap! !local version of single_lap_at_points! 232
# !local version of sparse_lap! !local version of single_lap_at_points! 233
# !local version of sparse_lap! !local version of single_lap_at_points! 234
# !local version of sparse_lap! !local version of single_lap_at_points! 235
# !local version of sparse_lap! !local version of single_lap_at_points! 236
# !local version of sparse_lap! !local version of single_lap_at_points! 237
# !local version of sparse_lap! !local version of single_lap_at_points! 238
# !local version of sparse_lap! !local version of single_lap_at_points! 239
# !local version of sparse_lap! !local version of single_lap_at_points! 240
# !local version of sparse_lap! !local version of single_lap_at_points! 241
# !local version of sparse_lap! !local version of single_lap_at_points! 242
# !local version of sparse_lap! !local version of single_lap_at_points! 243
# !local version of sparse_lap! !local version of single_lap_at_points! 244
# !local version of sparse_lap! !local version of single_lap_at_points! 245
# !local version of sparse_lap! !local version of single_lap_at_points! 246
# !local version of sparse_lap! !local version of single_lap_at_points! 247
# !local version of sparse_lap! !local version of single_lap_at_points! 248
# !local version of sparse_lap! !local version of single_lap_at_points! 249
# !local version of sparse_lap! !local version of single_lap_at_points! 250
# !local version of sparse_lap! !local version of single_lap_at_points! 251
# !local version of sparse_lap! !local version of single_lap_at_points! 252
# !local version of sparse_lap! !local version of single_lap_at_points! 253
# !local version of sparse_lap! !local version of single_lap_at_points! 254
# !local version of sparse_lap! !local version of single_lap_at_points! 255
# !local version of sparse_lap! !local version of single_lap_at_points! 256
# !local version of sparse_lap! !local version of single_lap_at_points! 257
# !local version of sparse_lap! !local version of single_lap_at_points! 258
# !local version of sparse_lap! !local version of single_lap_at_points! 259
# !local version of sparse_lap! !local version of single_lap_at_points! 260
# !local version of sparse_lap! !local version of single_lap_at_points! 261
# !local version of sparse_lap! !local version of single_lap_at_points! 262
# !local version of sparse_lap! !local version of single_lap_at_points! 263
# !local version of sparse_lap! !local version of single_lap_at_points! 264
# !local version of sparse_lap! !local version of single_lap_at_points! 265
# !local version of sparse_lap! !local version of single_lap_at_points! 266
# !local version of sparse_lap! !local version of single_lap_at_points! 267
# !local version of sparse_lap! !local version of single_lap_at_points! 268
# !local version of sparse_lap! !local version of single_lap_at_points! 269
# !local version of sparse_lap! !local version of single_lap_at_points! 270
# !local version of sparse_lap! !local version of single_lap_at_points! 271
# !local version of sparse_lap! !local version of single_lap_at_points! 272
# !local version of sparse_lap! !local version of single_lap_at_points! 273
# !local version of sparse_lap! !local version of single_lap_at_points! 274
# !local version of sparse_lap! !local version of single_lap_at_points! 275
# !local version of sparse_lap! !local version of single_lap_at_points! 276
# !local version of sparse_lap! !local version of single_lap_at_points! 277
# !local version of sparse_lap! !local version of single_lap_at_points! 278
# !local version of sparse_lap! !local version of single_lap_at_points! 279
# !local version of sparse_lap! !local version of single_lap_at_points! 280
# !local version of sparse_lap! !local version of single_lap_at_points! 281
# !local version of sparse_lap! !local version of single_lap_at_points! 282
# !local version of sparse_lap! !local version of single_lap_at_points! 283
# !local version of sparse_lap! !local version of single_lap_at_points! 284
# !local version of sparse_lap! !local version of single_lap_at_points! 285
# !local version of sparse_lap! !local version of single_lap_at_points! 286
# !local version of sparse_lap! !local version of single_lap_at_points! 287
# !local version of sparse_lap! !local version of single_lap_at_points! 288
# !local version of sparse_lap! !local version of single_lap_at_points! 289
# !local version of sparse_lap! !local version of single_lap_at_points! 290
# !local version of sparse_lap! !local version of single_lap_at_points! 291
# !local version of sparse_lap! !local version of single_lap_at_points! 292
# !local version of sparse_lap! !local version of single_lap_at_points! 293
# !local version of sparse_lap! !local version of single_lap_at_points! 294
# !local version of sparse_lap! !local version of single_lap_at_points! 295
# !local version of sparse_lap! !local version of single_lap_at_points! 296
# !local version of sparse_lap! !local version of single_lap_at_points! 297
# !local version of sparse_lap! !local version of single_lap_at_points! 298
# !local version of sparse_lap! !local version of single_lap_at_points! 299
# !local version of sparse_lap! !local version of single_lap_at_points! 300
# !local version of sparse_lap! !local version of single_lap_at_points! 301
# !local version of sparse_lap! !local version of single_lap_at_points! 302
# !local version of sparse_lap! !local version of single_lap_at_points! 303
# !local version of sparse_lap! !local version of single_lap_at_points! 304
# !local version of sparse_lap! !local version of single_lap_at_points! 305
# !local version of sparse_lap! !local version of single_lap_at_points! 306
# !local version of sparse_lap! !local version of single_lap_at_points! 307
# !local version of sparse_lap! !local version of single_lap_at_points! 308
# !local version of sparse_lap! !local version of single_lap_at_points! 309
# !local version of sparse_lap! !local version of single_lap_at_points! 310
# !local version of sparse_lap! !local version of single_lap_at_points! 311
# !local version of sparse_lap! !local version of single_lap_at_points! 312
# !local version of sparse_lap! !local version of single_lap_at_points! 313
# !local version of sparse_lap! !local version of single_lap_at_points! 314
# !local version of sparse_lap! !local version of single_lap_at_points! 315
# !local version of sparse_lap! !local version of single_lap_at_points! 316
# !local version of sparse_lap! !local version of single_lap_at_points! 317
# !local version of sparse_lap! !local version of single_lap_at_points! 318
# !local version of sparse_lap! !local version of single_lap_at_points! 319
# !local version of sparse_lap! !local version of single_lap_at_points! 320
# !local version of sparse_lap! !local version of single_lap_at_points! 321
# !local version of sparse_lap! !local version of single_lap_at_points! 322
# !local version of sparse_lap! !local version of single_lap_at_points! 323
# !local version of sparse_lap! !local version of single_lap_at_points! 324
# !local version of sparse_lap! !local version of single_lap_at_points! 325
# !local version of sparse_lap! !local version of single_lap_at_points! 326
# !local version of sparse_lap! !local version of single_lap_at_points! 327
# !local version of sparse_lap! !local version of single_lap_at_points! 328
# !local version of sparse_lap! !local version of single_lap_at_points! 329
# !local version of sparse_lap! !local version of single_lap_at_points! 330
# !local version of sparse_lap! !local version of single_lap_at_points! 331
# !local version of sparse_lap! !local version of single_lap_at_points! 332
# !local version of sparse_lap! !local version of single_lap_at_points! 333
# !local version of sparse_lap! !local version of single_lap_at_points! 334
# !local version of sparse_lap! !local version of single_lap_at_points! 335
# !local version of sparse_lap! !local version of single_lap_at_points! 336
# !local version of sparse_lap! !local version of single_lap_at_points! 337
# !local version of sparse_lap! !local version of single_lap_at_points! 338
# !local version of sparse_lap! !local version of single_lap_at_points! 339
# !local version of sparse_lap! !local version of single_lap_at_points! 340
# !local version of sparse_lap! !local version of single_lap_at_points! 341
# !local version of sparse_lap! !local version of single_lap_at_points! 342
# !local version of sparse_lap! !local version of single_lap_at_points! 343
# !local version of sparse_lap! !local version of single_lap_at_points! 344
# !local version of sparse_lap! !local version of single_lap_at_points! 345
# !local version of sparse_lap! !local version of single_lap_at_points! 346
# !local version of sparse_lap! !local version of single_lap_at_points! 347
# !local version of sparse_lap! !local version of single_lap_at_points! 348
# !local version of sparse_lap! !local version of single_lap_at_points! 349
# !local version of sparse_lap! !local version of single_lap_at_points! 350
# !local version of sparse_lap! !local version of single_lap_at_points! 351
# !local version of sparse_lap! !local version of single_lap_at_points! 352
# !local version of sparse_lap! !local version of single_lap_at_points! 353
# !local version of sparse_lap! !local version of single_lap_at_points! 354
# !local version of sparse_lap! !local version of single_lap_at_points! 355
# !local version of sparse_lap! !local version of single_lap_at_points! 356
# !local version of sparse_lap! !local version of single_lap_at_points! 357
# !local version of sparse_lap! !local version of single_lap_at_points! 358
# !local version of sparse_lap! !local version of single_lap_at_points! 359
# !local version of sparse_lap! !local version of single_lap_at_points! 360
# !local version of sparse_lap! !local version of single_lap_at_points! 361
# !local version of sparse_lap! !local version of single_lap_at_points! 362
# !local version of sparse_lap! !local version of single_lap_at_points! 363
# !local version of sparse_lap! !local version of single_lap_at_points! 364
# !local version of sparse_lap! !local version of single_lap_at_points! 365
# !local version of sparse_lap! !local version of single_lap_at_points! 366
# !local version of sparse_lap! !local version of single_lap_at_points! 367
# !local version of sparse_lap! !local version of single_lap_at_points! 368
# !local version of sparse_lap! !local version of single_lap_at_points! 369
# !local version of sparse_lap! !local version of single_lap_at_points! 370
# !local version of sparse_lap! !local version of single_lap_at_points! 371
# !local version of sparse_lap! !local version of single_lap_at_points! 372
# !local version of sparse_lap! !local version of single_lap_at_points! 373
# !local version of sparse_lap! !local version of single_lap_at_points! 374
# !local version of sparse_lap! !local version of single_lap_at_points! 375
# !local version of sparse_lap! !local version of single_lap_at_points! 376
# !local version of sparse_lap! !local version of single_lap_at_points! 377
# !local version of sparse_lap! !local version of single_lap_at_points! 378
# !local version of sparse_lap! !local version of single_lap_at_points! 379
# !local version of sparse_lap! !local version of single_lap_at_points! 380
# !local version of sparse_lap! !local version of single_lap_at_points! 381
# !local version of sparse_lap! !local version of single_lap_at_points! 382
# !local version of sparse_lap! !local version of single_lap_at_points! 383
# !local version of sparse_lap! !local version of single_lap_at_points! 384
# !local version of sparse_lap! !local version of single_lap_at_points! 385
# !local version of sparse_lap! !local version of single_lap_at_points! 386
# !local version of sparse_lap! !local version of single_lap_at_points! 387
# !local version of sparse_lap! !local version of single_lap_at_points! 388
# !local version of sparse_lap! !local version of single_lap_at_points! 389
# !local version of sparse_lap! !local version of single_lap_at_points! 390
# !local version of sparse_lap! !local version of single_lap_at_points! 391
# !local version of sparse_lap! !local version of single_lap_at_points! 392
# !local version of sparse_lap! !local version of single_lap_at_points! 393
# !local version of sparse_lap! !local version of single_lap_at_points! 394
# !local version of sparse_lap! !local version of single_lap_at_points! 395
# !local version of sparse_lap! !local version of single_lap_at_points! 396
# !local version of sparse_lap! !local version of single_lap_at_points! 397
# !local version of sparse_lap! !local version of single_lap_at_points! 398
# !local version of sparse_lap! !local version of single_lap_at_points! 399
# !local version of sparse_lap! !local version of single_lap_at_points! 400
# !local version of sparse_lap! !local version of single_lap_at_points! 401
# !local version of sparse_lap! !local version of single_lap_at_points! 402
# !local version of sparse_lap! !local version of single_lap_at_points! 403
# !local version of sparse_lap! !local version of single_lap_at_points! 404
# !local version of sparse_lap! !local version of single_lap_at_points! 405
# !local version of sparse_lap! !local version of single_lap_at_points! 406
# !local version of sparse_lap! !local version of single_lap_at_points! 407
# !local version of sparse_lap! !local version of single_lap_at_points! 408
# !local version of sparse_lap! !local version of single_lap_at_points! 409
# !local version of sparse_lap! !local version of single_lap_at_points! 410
# !local version of sparse_lap! !local version of single_lap_at_points! 411
# !local version of sparse_lap! !local version of single_lap_at_points! 412
# !local version of sparse_lap! !local version of single_lap_at_points! 413
# !local version of sparse_lap! !local version of single_lap_at_points! 414
# !local version of sparse_lap! !local version of single_lap_at_points! 415
# !local version of sparse_lap! !local version of single_lap_at_points! 416
# !local version of sparse_lap! !local version of single_lap_at_points! 417
# !local version of sparse_lap! !local version of single_lap_at_points! 418
# !local version of sparse_lap! !local version of single_lap_at_points! 419
# !local version of sparse_lap! !local version of single_lap_at_points! 420
# !local version of sparse_lap! !local version of single_lap_at_points! 421
# !local version of sparse_lap! !local version of single_lap_at_points! 422
# !local version of sparse_lap! !local version of single_lap_at_points! 423
# !local version of sparse_lap! !local version of single_lap_at_points! 424
# !local version of sparse_lap! !local version of single_lap_at_points! 425
# !local version of sparse_lap! !local version of single_lap_at_points! 426
# !local version of sparse_lap! !local version of single_lap_at_points! 427
# !local version of sparse_lap! !local version of single_lap_at_points! 428
# !local version of sparse_lap! !local version of single_lap_at_points! 429
# !local version of sparse_lap! !local version of single_lap_at_points! 430
# !local version of sparse_lap! !local version of single_lap_at_points! 431
# !local version of sparse_lap! !local version of single_lap_at_points! 432
# !local version of sparse_lap! !local version of single_lap_at_points! 433
# !local version of sparse_lap! !local version of single_lap_at_points! 434
# !local version of sparse_lap! !local version of single_lap_at_points! 435
# !local version of sparse_lap! !local version of single_lap_at_points! 436
# !local version of sparse_lap! !local version of single_lap_at_points! 437
# !local version of sparse_lap! !local version of single_lap_at_points! 438
# !local version of sparse_lap! !local version of single_lap_at_points! 439
# !local version of sparse_lap! !local version of single_lap_at_points! 440
# !local version of sparse_lap! !local version of single_lap_at_points! 441
# !local version of sparse_lap! !local version of single_lap_at_points! 442
# !local version of sparse_lap! !local version of single_lap_at_points! 443
# !local version of sparse_lap! !local version of single_lap_at_points! 444
# !local version of sparse_lap! !local version of single_lap_at_points! 445
# !local version of sparse_lap! !local version of single_lap_at_points! 446
# !local version of sparse_lap! !local version of single_lap_at_points! 447
# !local version of sparse_lap! !local version of single_lap_at_points! 448
# !local version of sparse_lap! !local version of single_lap_at_points! 449
# !local version of sparse_lap! !local version of single_lap_at_points! 450
# !local version of sparse_lap! !local version of single_lap_at_points! 451
# !local version of sparse_lap! !local version of single_lap_at_points! 452
# !local version of sparse_lap! !local version of single_lap_at_points! 453
# !local version of sparse_lap! !local version of single_lap_at_points! 454
# !local version of sparse_lap! !local version of single_lap_at_points! 455
# !local version of sparse_lap! !local version of single_lap_at_points! 456
# !local version of sparse_lap! !local version of single_lap_at_points! 457
# !local version of sparse_lap! !local version of single_lap_at_points! 458
# !local version of sparse_lap! !local version of single_lap_at_points! 459
# !local version of sparse_lap! !local version of single_lap_at_points! 460
# !local version of sparse_lap! !local version of single_lap_at_points! 461
# !local version of sparse_lap! !local version of single_lap_at_points! 462
# !local version of sparse_lap! !local version of single_lap_at_points! 463
# !local version of sparse_lap! !local version of single_lap_at_points! 464
# !local version of sparse_lap! !local version of single_lap_at_points! 465
# !local version of sparse_lap! !local version of single_lap_at_points! 466
# !local version of sparse_lap! !local version of single_lap_at_points! 467
# !local version of sparse_lap! !local version of single_lap_at_points! 468
# !local version of sparse_lap! !local version of single_lap_at_points! 469
# !local version of sparse_lap! !local version of single_lap_at_points! 470
# !local version of sparse_lap! !local version of single_lap_at_points! 471
# !local version of sparse_lap! !local version of single_lap_at_points! 472
# !local version of sparse_lap! !local version of single_lap_at_points! 473
# !local version of sparse_lap! !local version of single_lap_at_points! 474
# !local version of sparse_lap! !local version of single_lap_at_points! 475
# !local version of sparse_lap! !local version of single_lap_at_points! 476
# !local version of sparse_lap! !local version of single_lap_at_points! 477
# !local version of sparse_lap! !local version of single_lap_at_points! 478
# !local version of sparse_lap! !local version of single_lap_at_points! 479
# !local version of sparse_lap! !local version of single_lap_at_points! 480
# !local version of sparse_lap! !local version of single_lap_at_points! 481
# !local version of sparse_lap! !local version of single_lap_at_points! 482
# !local version of sparse_lap! !local version of single_lap_at_points! 483
# !local version of sparse_lap! !local version of single_lap_at_points! 484
# !local version of sparse_lap! !local version of single_lap_at_points! 485
# !local version of sparse_lap! !local version of single_lap_at_points! 486
# !local version of sparse_lap! !local version of single_lap_at_points! 487
# !local version of sparse_lap! !local version of single_lap_at_points! 488
# !local version of sparse_lap! !local version of single_lap_at_points! 489
# !local version of sparse_lap! !local version of single_lap_at_points! 490
# !local version of sparse_lap! !local version of single_lap_at_points! 491
# !local version of sparse_lap! !local version of single_lap_at_points! 492
# !local version of sparse_lap! !local version of single_lap_at_points! 493
# !local version of sparse_lap! !local version of single_lap_at_points! 494
# !local version of sparse_lap! !local version of single_lap_at_points! 495
# !local version of sparse_lap! !local version of single_lap_at_points! 496
# !local version of sparse_lap! !local version of single_lap_at_points! 497
# !local version of sparse_lap! !local version of single_lap_at_points! 498
# !local version of sparse_lap! !local version of single_lap_at_points! 499
# !local version of sparse_lap! !local version of single_lap_at_points! 500
# !local version of sparse_lap! !local version of single_lap_at_points! 501
# !local version of sparse_lap! !local version of single_lap_at_points! 502
# !local version of sparse_lap! !local version of single_lap_at_points! 503
# !local version of sparse_lap! !local version of single_lap_at_points! 504
# !local version of sparse_lap! !local version of single_lap_at_points! 505
# !local version of sparse_lap! !local version of single_lap_at_points! 506
# !local version of sparse_lap! !local version of single_lap_at_points! 507
# !local version of sparse_lap! !local version of single_lap_at_points! 508
# !local version of sparse_lap! !local version of single_lap_at_points! 509
# !local version of sparse_lap! !local version of single_lap_at_points! 510
# !local version of sparse_lap! !local version of single_lap_at_points! 511
# !local version of sparse_lap! !local version of single_lap_at_points! 512
# !local version of sparse_lap! !local version of single_lap_at_points! 513
# !local version of sparse_lap! !local version of single_lap_at_points! 514
# !local version of sparse_lap! !local version of single_lap_at_points! 515
# !local version of sparse_lap! !local version of single_lap_at_points! 516
# !local version of sparse_lap! !local version of single_lap_at_points! 517
# !local version of sparse_lap! !local version of single_lap_at_points! 518
# !local version of sparse_lap! !local version of single_lap_at_points! 519
# !local version of sparse_lap! !local version of single_lap_at_points! 520
# !local version of sparse_lap! !local version of single_lap_at_points! 521
# !local version of sparse_lap! !local version of single_lap_at_points! 522
# !local version of sparse_lap! !local version of single_lap_at_points! 523
# !local version of sparse_lap! !local version of single_lap_at_points! 524
# !local version of sparse_lap! !local version of single_lap_at_points! 525
# !local version of sparse_lap! !local version of single_lap_at_points! 526
# !local version of sparse_lap! !local version of single_lap_at_points! 527
# !local version of sparse_lap! !local version of single_lap_at_points! 528
# !local version of sparse_lap! !local version of single_lap_at_points! 529
# !local version of sparse_lap! !local version of single_lap_at_points! 530
# !local version of sparse_lap! !local version of single_lap_at_points! 531
# !local version of sparse_lap! !local version of single_lap_at_points! 532
# !local version of sparse_lap! !local version of single_lap_at_points! 533
# !local version of sparse_lap! !local version of single_lap_at_points! 534
# !local version of sparse_lap! !local version of single_lap_at_points! 535
# !local version of sparse_lap! !local version of single_lap_at_points! 536
# !local version of sparse_lap! !local version of single_lap_at_points! 537
# !local version of sparse_lap! !local version of single_lap_at_points! 538
# !local version of sparse_lap! !local version of single_lap_at_points! 539
# !local version of sparse_lap! !local version of single_lap_at_points! 540
# !local version of sparse_lap! !local version of single_lap_at_points! 541
# !local version of sparse_lap! !local version of single_lap_at_points! 542
# !local version of sparse_lap! !local version of single_lap_at_points! 543
# !local version of sparse_lap! !local version of single_lap_at_points! 544
# !local version of sparse_lap! !local version of single_lap_at_points! 545
# !local version of sparse_lap! !local version of single_lap_at_points! 546
# !local version of sparse_lap! !local version of single_lap_at_points! 547
# !local version of sparse_lap! !local version of single_lap_at_points! 548
# !local version of sparse_lap! !local version of single_lap_at_points! 549
# !local version of sparse_lap! !local version of single_lap_at_points! 550
# !local version of sparse_lap! !local version of single_lap_at_points! 551
# !local version of sparse_lap! !local version of single_lap_at_points! 552
# !local version of sparse_lap! !local version of single_lap_at_points! 553
# !local version of sparse_lap! !local version of single_lap_at_points! 554
# !local version of sparse_lap! !local version of single_lap_at_points! 555
# !local version of sparse_lap! !local version of single_lap_at_points! 556
# !local version of sparse_lap! !local version of single_lap_at_points! 557
# !local version of sparse_lap! !local version of single_lap_at_points! 558
# !local version of sparse_lap! !local version of single_lap_at_points! 559
# !local version of sparse_lap! !local version of single_lap_at_points! 560
# !local version of sparse_lap! !local version of single_lap_at_points! 561
# !local version of sparse_lap! !local version of single_lap_at_points! 562
# !local version of sparse_lap! !local version of single_lap_at_points! 563
# !local version of sparse_lap! !local version of single_lap_at_points! 564
# !local version of sparse_lap! !local version of single_lap_at_points! 565
# !local version of sparse_lap! !local version of single_lap_at_points! 566
# !local version of sparse_lap! !local version of single_lap_at_points! 567
# !local version of sparse_lap! !local version of single_lap_at_points! 568
# !local version of sparse_lap! !local version of single_lap_at_points! 569
# !local version of sparse_lap! !local version of single_lap_at_points! 570
# !local version of sparse_lap! !local version of single_lap_at_points! 571
# !local version of sparse_lap! !local version of single_lap_at_points! 572
# !local version of sparse_lap! !local version of single_lap_at_points! 573
# !local version of sparse_lap! !local version of single_lap_at_points! 574
# !local version of sparse_lap! !local version of single_lap_at_points! 575
# !local version of sparse_lap! !local version of single_lap_at_points! 576
# !local version of sparse_lap! !local version of single_lap_at_points! 577
# !local version of sparse_lap! !local version of single_lap_at_points! 578
# !local version of sparse_lap! !local version of single_lap_at_points! 579
# !local version of sparse_lap! !local version of single_lap_at_points! 580
# !local version of sparse_lap! !local version of single_lap_at_points! 581
# !local version of sparse_lap! !local version of single_lap_at_points! 582
# !local version of sparse_lap! !local version of single_lap_at_points! 583
# !local version of sparse_lap! !local version of single_lap_at_points! 584
# !local version of sparse_lap! !local version of single_lap_at_points! 585
# !local version of sparse_lap! !local version of single_lap_at_points! 586
# !local version of sparse_lap! !local version of single_lap_at_points! 587
# !local version of sparse_lap! !local version of single_lap_at_points! 588
# !local version of sparse_lap! !local version of single_lap_at_points! 589
# !local version of sparse_lap! !local version of single_lap_at_points! 590
# !local version of sparse_lap! !local version of single_lap_at_points! 591
# !local version of sparse_lap! !local version of single_lap_at_points! 592
# !local version of sparse_lap! !local version of single_lap_at_points! 593
# !local version of sparse_lap! !local version of single_lap_at_points! 594
# !local version of sparse_lap! !local version of single_lap_at_points! 595
# !local version of sparse_lap! !local version of single_lap_at_points! 596
# !local version of sparse_lap! !local version of single_lap_at_points! 597
# !local version of sparse_lap! !local version of single_lap_at_points! 598
# !local version of sparse_lap! !local version of single_lap_at_points! 599
# !local version of sparse_lap! !local version of single_lap_at_points! 600
# !local version of sparse_lap! !local version of single_lap_at_points! 601
# !local version of sparse_lap! !local version of single_lap_at_points! 602
# !local version of sparse_lap! !local version of single_lap_at_points! 603
# !local version of sparse_lap! !local version of single_lap_at_points! 604
# !local version of sparse_lap! !local version of single_lap_at_points! 605
# !local version of sparse_lap! !local version of single_lap_at_points! 606
# !local version of sparse_lap! !local version of single_lap_at_points! 607
# !local version of sparse_lap! !local version of single_lap_at_points! 608
# !local version of sparse_lap! !local version of single_lap_at_points! 609
# !local version of sparse_lap! !local version of single_lap_at_points! 610
# !local version of sparse_lap! !local version of single_lap_at_points! 611
# !local version of sparse_lap! !local version of single_lap_at_points! 612
# !local version of sparse_lap! !local version of single_lap_at_points! 613
# !local version of sparse_lap! !local version of single_lap_at_points! 614
# !local version of sparse_lap! !local version of single_lap_at_points! 615
# !local version of sparse_lap! !local version of single_lap_at_points! 616
# !local version of sparse_lap! !local version of single_lap_at_points! 617
# !local version of sparse_lap! !local version of single_lap_at_points! 618
# !local version of sparse_lap! !local version of single_lap_at_points! 619
# !local version of sparse_lap! !local version of single_lap_at_points! 620
# !local version of sparse_lap! !local version of single_lap_at_points! 621
# !local version of sparse_lap! !local version of single_lap_at_points! 622
# !local version of sparse_lap! !local version of single_lap_at_points! 623
# !local version of sparse_lap! !local version of single_lap_at_points! 624
# !local version of sparse_lap! !local version of single_lap_at_points! 625
# !local version of sparse_lap! !local version of single_lap_at_points! 626
# !local version of sparse_lap! !local version of single_lap_at_points! 627
# !local version of sparse_lap! !local version of single_lap_at_points! 628
# !local version of sparse_lap! !local version of single_lap_at_points! 629
# !local version of sparse_lap! !local version of single_lap_at_points! 630
# !local version of sparse_lap! !local version of single_lap_at_points! 631
# !local version of sparse_lap! !local version of single_lap_at_points! 632
# !local version of sparse_lap! !local version of single_lap_at_points! 633
# !local version of sparse_lap! !local version of single_lap_at_points! 634
# !local version of sparse_lap! !local version of single_lap_at_points! 635
# !local version of sparse_lap! !local version of single_lap_at_points! 636
# !local version of sparse_lap! !local version of single_lap_at_points! 637
# !local version of sparse_lap! !local version of single_lap_at_points! 638
# !local version of sparse_lap! !local version of single_lap_at_points! 639
# !local version of sparse_lap! !local version of single_lap_at_points! 640
# !local version of sparse_lap! !local version of single_lap_at_points! 641
# !local version of sparse_lap! !local version of single_lap_at_points! 642
# !local version of sparse_lap! !local version of single_lap_at_points! 643
# !local version of sparse_lap! !local version of single_lap_at_points! 644
# !local version of sparse_lap! !local version of single_lap_at_points! 645
# !local version of sparse_lap! !local version of single_lap_at_points! 646
# !local version of sparse_lap! !local version of single_lap_at_points! 647
# !local version of sparse_lap! !local version of single_lap_at_points! 648
# !local version of sparse_lap! !local version of single_lap_at_points! 649
# !local version of sparse_lap! !local version of single_lap_at_points! 650
# ...
# !local version of sparse_lap! !local version of single_lap_at_points! 786
# !local version of sparse_lap! !local version of single_lap_at_points! 787
# !local version of sparse_lap! !local version of single_lap_at_points! 788
# !local version of sparse_lap! !local version of single_lap_at_points! 789
# !local version of sparse_lap! !local version of single_lap_at_points! 790
# !local version of sparse_lap! !local version of single_lap_at_points! 791
# !local version of sparse_lap! !local version of single_lap_at_points! 792
# !local version of sparse_lap! !local version of single_lap_at_points! 793
# !local version of sparse_lap! !local version of single_lap_at_points! 794
# !local version of sparse_lap! !local version of single_lap_at_points! 795
# !local version of sparse_lap! !local version of single_lap_at_points! 796
# !local version of sparse_lap! !local version of single_lap_at_points! 797
# !local version of sparse_lap! !local version of single_lap_at_points! 798
# !local version of sparse_lap! !local version of single_lap_at_points! 799
# !local version of sparse_lap! !local version of single_lap_at_points! 800
# !local version of sparse_lap! !local version of single_lap_at_points! 801
# !local version of sparse_lap! !local version of single_lap_at_points! 802
# !local version of sparse_lap! !local version of single_lap_at_points! 803
# !local version of sparse_lap! !local version of single_lap_at_points! 804
# !local version of sparse_lap! !local version of single_lap_at_points! 805
# !local version of sparse_lap! !local version of single_lap_at_points! 806
# !local version of sparse_lap! !local version of single_lap_at_points! 807
# !local version of sparse_lap! !local version of single_lap_at_points! 808
# !local version of sparse_lap! !local version of single_lap_at_points! 809
# !local version of sparse_lap! !local version of single_lap_at_points! 810
# !local version of sparse_lap! !local version of single_lap_at_points! 811
# !local version of sparse_lap! !local version of single_lap_at_points! 812
# !local version of sparse_lap! !local version of single_lap_at_points! 813
# !local version of sparse_lap! !local version of single_lap_at_points! 814
# !local version of sparse_lap! !local version of single_lap_at_points! 815
# !local version of sparse_lap! !local version of single_lap_at_points! 816
# !local version of sparse_lap! !local version of single_lap_at_points! 817
# !local version of sparse_lap! !local version of single_lap_at_points! 818
# !local version of sparse_lap! !local version of single_lap_at_points! 819
# !local version of sparse_lap! !local version of single_lap_at_points! 820
# !local version of sparse_lap! !local version of single_lap_at_points! 821
# !local version of sparse_lap! !local version of single_lap_at_points! 822
# !local version of sparse_lap! !local version of single_lap_at_points! 823
# !local version of sparse_lap! !local version of single_lap_at_points! 824
# !local version of sparse_lap! !local version of single_lap_at_points! 825
# !local version of sparse_lap! !local version of single_lap_at_points! 826
# !local version of sparse_lap! !local version of single_lap_at_points! 827
# !local version of sparse_lap! !local version of single_lap_at_points! 828
# !local version of sparse_lap! !local version of single_lap_at_points! 829
# !local version of sparse_lap! !local version of single_lap_at_points! 830
# !local version of sparse_lap! !local version of single_lap_at_points! 831
# !local version of sparse_lap! !local version of single_lap_at_points! 832
# !local version of sparse_lap! !local version of single_lap_at_points! 833
# !local version of sparse_lap! !local version of single_lap_at_points! 834
# !local version of sparse_lap! !local version of single_lap_at_points! 835
# !local version of sparse_lap! !local version of single_lap_at_points! 836
# !local version of sparse_lap! !local version of single_lap_at_points! 837
# !local version of sparse_lap! !local version of single_lap_at_points! 838
# !local version of sparse_lap! !local version of single_lap_at_points! 839
# !local version of sparse_lap! !local version of single_lap_at_points! 840
# !local version of sparse_lap! !local version of single_lap_at_points! 841
# !local version of sparse_lap! !local version of single_lap_at_points! 842
# !local version of sparse_lap! !local version of single_lap_at_points! 843
# !local version of sparse_lap! !local version of single_lap_at_points! 844
# !local version of sparse_lap! !local version of single_lap_at_points! 845
# !local version of sparse_lap! !local version of single_lap_at_points! 846
# !local version of sparse_lap! !local version of single_lap_at_points! 847
# !local version of sparse_lap! !local version of single_lap_at_points! 848
# !local version of sparse_lap! !local version of single_lap_at_points! 849
# !local version of sparse_lap! !local version of single_lap_at_points! 850
# !local version of sparse_lap! !local version of single_lap_at_points! 851
# !local version of sparse_lap! !local version of single_lap_at_points! 852
# !local version of sparse_lap! !local version of single_lap_at_points! 853
# !local version of sparse_lap! !local version of single_lap_at_points! 854
# !local version of sparse_lap! !local version of single_lap_at_points! 855
# !local version of sparse_lap! !local version of single_lap_at_points! 856
# !local version of sparse_lap! !local version of single_lap_at_points! 857
# !local version of sparse_lap! !local version of single_lap_at_points! 858
# !local version of sparse_lap! !local version of single_lap_at_points! 859
# !local version of sparse_lap! !local version of single_lap_at_points! 860
# !local version of sparse_lap! !local version of single_lap_at_points! 861
# !local version of sparse_lap! !local version of single_lap_at_points! 862
# !local version of sparse_lap! !local version of single_lap_at_points! 863
# !local version of sparse_lap! !local version of single_lap_at_points! 864
# !local version of sparse_lap! !local version of single_lap_at_points! 865
# !local version of sparse_lap! !local version of single_lap_at_points! 866
# !local version of sparse_lap! !local version of single_lap_at_points! 867
# !local version of sparse_lap! !local version of single_lap_at_points! 868
# !local version of sparse_lap! !local version of single_lap_at_points! 869
# !local version of sparse_lap! !local version of single_lap_at_points! 870
# !local version of sparse_lap! !local version of single_lap_at_points! 871
# !local version of sparse_lap! !local version of single_lap_at_points! 872
# !local version of sparse_lap! !local version of single_lap_at_points! 873
# !local version of sparse_lap! !local version of single_lap_at_points! 874
# !local version of sparse_lap! !local version of single_lap_at_points! 875
# !local version of sparse_lap! !local version of single_lap_at_points! 876
# !local version of sparse_lap! !local version of single_lap_at_points! 877
# !local version of sparse_lap! !local version of single_lap_at_points! 878
# !local version of sparse_lap! !local version of single_lap_at_points! 879
# !local version of sparse_lap! !local version of single_lap_at_points! 880
# !local version of sparse_lap! !local version of single_lap_at_points! 881
# !local version of sparse_lap! !local version of single_lap_at_points! 882
# !local version of sparse_lap! !local version of single_lap_at_points! 883
# !local version of sparse_lap! !local version of single_lap_at_points! 884
# !local version of sparse_lap! !local version of single_lap_at_points! 885
# !local version of sparse_lap! !local version of single_lap_at_points! 886
# !local version of sparse_lap! !local version of single_lap_at_points! 887
# !local version of sparse_lap! !local version of single_lap_at_points! 888
# !local version of sparse_lap! !local version of single_lap_at_points! 889
# !local version of sparse_lap! !local version of single_lap_at_points! 890
# !local version of sparse_lap! !local version of single_lap_at_points! 891
# !local version of sparse_lap! !local version of single_lap_at_points! 892
# !local version of sparse_lap! !local version of single_lap_at_points! 893
# !local version of sparse_lap! !local version of single_lap_at_points! 894
# !local version of sparse_lap! !local version of single_lap_at_points! 895
# !local version of sparse_lap! !local version of single_lap_at_points! 896
# !local version of sparse_lap! !local version of single_lap_at_points! 897
# !local version of sparse_lap! !local version of single_lap_at_points! 898
# !local version of sparse_lap! !local version of single_lap_at_points! 899
# !local version of sparse_lap! !local version of single_lap_at_points! 900
# !local version of sparse_lap! !local version of single_lap_at_points! 901
# !local version of sparse_lap! !local version of single_lap_at_points! 902
# !local version of sparse_lap! !local version of single_lap_at_points! 903
# !local version of sparse_lap! !local version of single_lap_at_points! 904
# !local version of sparse_lap! !local version of single_lap_at_points! 905
# !local version of sparse_lap! !local version of single_lap_at_points! 906
# !local version of sparse_lap! !local version of single_lap_at_points! 907
# !local version of sparse_lap! !local version of single_lap_at_points! 908
# !local version of sparse_lap! !local version of single_lap_at_points! 909
# !local version of sparse_lap! !local version of single_lap_at_points! 910
# !local version of sparse_lap! !local version of single_lap_at_points! 911
# !local version of sparse_lap! !local version of single_lap_at_points! 912
# !local version of sparse_lap! !local version of single_lap_at_points! 913
# !local version of sparse_lap! !local version of single_lap_at_points! 914
# !local version of sparse_lap! !local version of single_lap_at_points! 915
# !local version of sparse_lap! !local version of single_lap_at_points! 916
# !local version of sparse_lap! !local version of single_lap_at_points! 917
# !local version of sparse_lap! !local version of single_lap_at_points! 918
# !local version of sparse_lap! !local version of single_lap_at_points! 919
# !local version of sparse_lap! !local version of single_lap_at_points! 920
# !local version of sparse_lap! !local version of single_lap_at_points! 921
# !local version of sparse_lap! !local version of single_lap_at_points! 922
# !local version of sparse_lap! !local version of single_lap_at_points! 923
# !local version of sparse_lap! !local version of single_lap_at_points! 924
# !local version of sparse_lap! !local version of single_lap_at_points! 925
# !local version of sparse_lap! !local version of single_lap_at_points! 926
# !local version of sparse_lap! !local version of single_lap_at_points! 927
# !local version of sparse_lap! !local version of single_lap_at_points! 928
# !local version of sparse_lap! !local version of single_lap_at_points! 929
# !local version of sparse_lap! !local version of single_lap_at_points! 930
# !local version of sparse_lap! !local version of single_lap_at_points! 931
# !local version of sparse_lap! !local version of single_lap_at_points! 932
# !local version of sparse_lap! !local version of single_lap_at_points! 933
# !local version of sparse_lap! !local version of single_lap_at_points! 934
# !local version of sparse_lap! !local version of single_lap_at_points! 935
# !local version of sparse_lap! !local version of single_lap_at_points! 936
# !local version of sparse_lap! !local version of single_lap_at_points! 937
# !local version of sparse_lap! !local version of single_lap_at_points! 938
# !local version of sparse_lap! !local version of single_lap_at_points! 939
# !local version of sparse_lap! !local version of single_lap_at_points! 940
# !local version of sparse_lap! !local version of single_lap_at_points! 941
# !local version of sparse_lap! !local version of single_lap_at_points! 942
# !local version of sparse_lap! !local version of single_lap_at_points! 943
# !local version of sparse_lap! !local version of single_lap_at_points! 944
# !local version of sparse_lap! !local version of single_lap_at_points! 945
# !local version of sparse_lap! !local version of single_lap_at_points! 946
# !local version of sparse_lap! !local version of single_lap_at_points! 947
# !local version of sparse_lap! !local version of single_lap_at_points! 948
# !local version of sparse_lap! !local version of single_lap_at_points! 949
# !local version of sparse_lap! !local version of single_lap_at_points! 950
# !local version of sparse_lap! !local version of single_lap_at_points! 951
# !local version of sparse_lap! !local version of single_lap_at_points! 952
# !local version of sparse_lap! !local version of single_lap_at_points! 953
# !local version of sparse_lap! !local version of single_lap_at_points! 954
# !local version of sparse_lap! !local version of single_lap_at_points! 955
# !local version of sparse_lap! !local version of single_lap_at_points! 956
# !local version of sparse_lap! !local version of single_lap_at_points! 957
# !local version of sparse_lap! !local version of single_lap_at_points! 958
# !local version of sparse_lap! !local version of single_lap_at_points! 959
# !local version of sparse_lap! !local version of single_lap_at_points! 960
# !local version of sparse_lap! !local version of single_lap_at_points! 961
# !local version of sparse_lap! !local version of single_lap_at_points! 962
# !local version of sparse_lap! !local version of single_lap_at_points! 963
# !local version of sparse_lap! !local version of single_lap_at_points! 964
# !local version of sparse_lap! !local version of single_lap_at_points! 965
# !local version of sparse_lap! !local version of single_lap_at_points! 966
# !local version of sparse_lap! !local version of single_lap_at_points! 967
# !local version of sparse_lap! !local version of single_lap_at_points! 968
# !local version of sparse_lap! !local version of single_lap_at_points! 969
# !local version of sparse_lap! !local version of single_lap_at_points! 970
# !local version of sparse_lap! !local version of single_lap_at_points! 971
# !local version of sparse_lap! !local version of single_lap_at_points! 972
# !local version of sparse_lap! !local version of single_lap_at_points! 973
# !local version of sparse_lap! !local version of single_lap_at_points! 974
# !local version of sparse_lap! !local version of single_lap_at_points! 975
# !local version of sparse_lap! !local version of single_lap_at_points! 976
# !local version of sparse_lap! !local version of single_lap_at_points! 977
# !local version of sparse_lap! !local version of single_lap_at_points! 978
# !local version of sparse_lap! !local version of single_lap_at_points! 979
# !local version of sparse_lap! !local version of single_lap_at_points! 980
# !local version of sparse_lap! !local version of single_lap_at_points! 981
# !local version of sparse_lap! !local version of single_lap_at_points! 982
# !local version of sparse_lap! !local version of single_lap_at_points! 983
# !local version of sparse_lap! !local version of single_lap_at_points! 984
# !local version of sparse_lap! !local version of single_lap_at_points! 985
# !local version of sparse_lap! !local version of single_lap_at_points! 986
# !local version of sparse_lap! !local version of single_lap_at_points! 987
# !local version of sparse_lap! !local version of single_lap_at_points! 988
# !local version of sparse_lap! !local version of single_lap_at_points! 989
# !local version of sparse_lap! !local version of single_lap_at_points! 990
# !local version of sparse_lap! !local version of single_lap_at_points! 991
# !local version of sparse_lap! !local version of single_lap_at_points! 992
# !local version of sparse_lap! !local version of single_lap_at_points! 993
# !local version of sparse_lap! !local version of single_lap_at_points! 994
# !local version of sparse_lap! !local version of single_lap_at_points! 995
# !local version of sparse_lap! !local version of single_lap_at_points! 996
# !local version of sparse_lap! !local version of single_lap_at_points! 997
# !local version of sparse_lap! !local version of single_lap_at_points! 998
# !local version of sparse_lap! !local version of single_lap_at_points! 999
# !local version of sparse_lap! !local version of single_lap_at_points! 1000
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # See results

# %%
println("nccs")
println("mean: ", mean(nccs))
println("minimum: ", minimum(nccs))
println("maximum: ", maximum(nccs))
# Out:
# nccs
# mean: 0.2185550293579995
# minimum: -0.1684818684100581
# maximum: 0.5159404756495471

# %%
h = fit(Histogram, nccs)
# Out:
# Histogram{Int64,1,Tuple{StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}}}
# edges:
#   -0.2:0.1:0.6
# weights: [21, 49, 128, 239, 212, 256, 87, 8]
# closed: left
# isdensity: false

# %%
using PyPlot
h = plt.hist(nccs, 20);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Conclusion
#
# There is correlation between

# %% [markdown]
# # Functions

# %%
function sparse_lap(img,
                    imgw,
                    fhs,
                    window_size;
                    spacing::Integer=25,
                    point_count::Integer=100,
                    timer::TimerOutput=TimerOutput("sparse_lap"),
                    new_version=true)
    print("!local version of sparse_lap! ")
    mask = parent(padarray(trues(size(img).-(2*fhs, 2*fhs)), Fill(false, (fhs, fhs), (fhs, fhs))))
    @timeit_debug timer "find edge points" begin
        inds = find_edge_points(img, spacing=spacing, number=point_count, mask=mask)
    end
    @timeit_debug timer "sparse lap" begin
        new_estim_at_inds, err = single_lap_at_points(img, imgw, fhs, window_size, inds, 3, timer=timer)
    end
    if all(isnan, new_estim_at_inds)
        @timeit_debug timer "interpolate flow" begin
            full_new_estim = zeros(size(img)) .* im .+ zeros(size(img))
        end
    else
        @timeit_debug timer "interpolate flow" begin
            full_new_estim = interpolate_flow(new_estim_at_inds, inds, size(img))
        end
    end
    @timeit_debug timer "generate source_reg" begin
        source_reg = warp_img(imgw, real(full_new_estim), imag(full_new_estim))
    end
    return full_new_estim, source_reg, err, new_estim_at_inds, inds
end


function single_lap_at_points(image_1::Image,
                              image_2::Image,
                              filter_half_size::Integer,
                              window,
                              inds::Array{CartesianIndex,1},
                              filter_num::Integer=3;
                              timer::TimerOutput=TimerOutput("Sparse LAP"),
                              display::Bool=false)
    
    print("!local version of single_lap_at_points! ")

    image_size = size(image_1)
    pixel_count = length(image_1)
    ind_count = length(inds)
    filter_size = 2 * filter_half_size + 1

    # Prepare filters:
    # Calculate separable filters from basis:
    sigma = (filter_half_size + 2) / 4
    centered_inds = centered(-filter_half_size:filter_half_size)
    gaus = gaussian(sigma, filter_size)
    gaus_der = gaus .* centered_inds .* (-1)/sigma^2
    gaus_der_flip = reverse(gaus_der, dims=1)

    # prepare 2D filter basis for later use
    basis = similar(image_1, (filter_size, filter_size, filter_num))

    # dif = (points of forward image - points of backward image) for each filter
    dif = similar(image_1, (image_size..., filter_num))

    @timeit_debug timer "filtering" begin
        if filter_num == 3
            # temporary place to store filtered images
            tmp_filtered_1 = fill(NaN, image_size)
            tmp_filtered_2 = fill(NaN, image_size)

            # basis 1 - (gaus, gaus) both forward and backward
            kernf_1 = kernelfactors((gaus, gaus))
            basis[:, :, 1] = broadcast(*, kernf_1...)
            # filt_onebyone!(tmp_filtered_1, image_1, kernf_1, filter_half_size, points)
            # filt_onebyone!(tmp_filtered_2, image_2, kernf_1, filter_half_size, points)
            imfilter!(tmp_filtered_1, image_1, kernf_1, "symmetric")
            imfilter!(tmp_filtered_2, image_2, kernf_1, "symmetric")
            dif[:, :, 1] = tmp_filtered_2 - tmp_filtered_1

            # basis 2 - (gaus, gaus_der_flip) as forward, (gaus, gaus_der) as backward
            kernf_2f = kernelfactors((gaus, gaus_der_flip))
            basis[:, :, 2] = broadcast(*, kernf_2f...)
            # filt_onebyone!(tmp_filtered_1, image_1, kernf_2f, filter_half_size, points)
            imfilter!(tmp_filtered_1, image_1, kernf_2f, "symmetric")
            kernf_2b = kernelfactors((gaus, gaus_der))
            # filt_onebyone!(tmp_filtered_2, image_2, kernf_2b, filter_half_size, points)
            imfilter!(tmp_filtered_2, image_2, kernf_2b, "symmetric")
            dif[:, :, 2] = tmp_filtered_2 - tmp_filtered_1

            # basis 3 - (gaus_der_flip, gaus) as forward, (gaus_der, gaus) as backward
            kernf_3f = kernelfactors((gaus_der_flip, gaus))
            basis[:, :, 3] = broadcast(*, kernf_3f...)
            # filt_onebyone!(tmp_filtered_1, image_1, kernf_3f, filter_half_size, points)
            imfilter!(tmp_filtered_1, image_1, kernf_3f, "symmetric")
            kernf_3b = kernelfactors((gaus_der, gaus))
            # filt_onebyone!(tmp_filtered_2, image_2, kernf_3b, filter_half_size, points)
            imfilter!(tmp_filtered_2, image_2, kernf_3b, "symmetric")
            dif[:, :, 3] = tmp_filtered_2 - tmp_filtered_1
        end
    end # "filtering"

    dif = reshape(dif, (:, filter_num))

    # prepare matrices for linear system of equations
    # A = zeros(filter_num-1, filter_num-1, pixel_count)
    # b = zeros(filter_num-1, pixel_count)
    A = similar(image_1, (filter_num-1, filter_num-1, ind_count))
    b = similar(image_1, (filter_num-1, ind_count))

    @timeit_debug timer "prepare A and b" begin
        # TODO: check whether window_sum_around_points calculates only around points and not on whole window.
        for k in 1:filter_num-1
            for l in k:filter_num-1
                @timeit_debug timer "window sum part 1" begin
                    # @views window_sum_around_points!(A[k, l, :], dif[:, k+1] .* dif[:, l+1], image_size, window, points)
                    @views window_sum3_at_inds!(A[k, l, :], dif[:, k+1] .* dif[:, l+1], image_size, window, inds)
                    A[l, k, :] = A[k, l, :]
                end
            end
            @timeit_debug timer "window sum part 2" begin
                # @views window_sum_around_points!(b[k, :], dif[:, k+1] .* dif[:, 1] .* (-1), image_size, window, points)
                @views window_sum3_at_inds!(b[k, :], dif[:, k+1] .* dif[:, 1] .* (-1), image_size, window, inds)
            end
        end
    end # "prepare A and b"

    # Perform Gauss elimination on all pixels in parallel:
    # coeffs will be of shape: pixel_count, filter_num-1
    @timeit_debug timer "multi mat div" begin
        @views coeffs = multi_mat_div_qr(A, b)
    end

    # adding ones so that all base filters have their coefficients even the first one
    all_coeffs = [ones(ind_count) coeffs]

    k = (-filter_half_size:filter_half_size)

    # Get the displacement vector field from the filters
    @timeit_debug timer "calculate flow" begin
        u_est_at_inds = similar(image_1, ComplexF64, ind_count)
        @views u_est_at_inds[:] = 2 .* ((im .* (.-1 .* all_coeffs[:, 3]) ./ all_coeffs[:, 1]) .+ ((.-1 .* all_coeffs[:, 2]) ./ all_coeffs[:, 1]));
    end # "calculate flow"

    # dont use estimations whose displacement is larger than the filter_half_size

    # u_est_at_inds[(real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2] .= NaN .+ NaN .* 1im;
    # println(u_est_at_inds[(real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2],
    #         inds[(real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2])
    # println(count((real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2))

    addpoints(inds[(real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2])
    addpoints(inds[.!((real(u_est_at_inds).^2 .+ imag(u_est_at_inds).^2) .> filter_half_size^2)])

    err = sum(all_coeffs .* dif[map(x -> to_lin_index(x, image_size), inds), :], dims=2)

    dif = reshape(dif, (image_size..., filter_num))

    window = (5,5)
    whs = round.(Int64, (window.-(1,1))./2)
    shift = CartesianIndex(whs)

    @timeit_debug timer "calc residual" begin
        for (k, ind) in enumerate(inds)
            err[k] = sum(dif[:,:, 1][ind-shift:ind+shift].^2 .+
                        (dif[:,:, 2][ind-shift:ind+shift] .* all_coeffs[k, 2]) .^2 .+
                        (dif[:,:, 3][ind-shift:ind+shift] .* all_coeffs[k, 3]) .^2)
        end
    end

    return u_est_at_inds, err

end
# Out:
# single_lap_at_points (generic function with 2 methods)
