# %% [markdown]
# # Test Registration Functions

# %% [markdown]
# In this example page I will show how the registration algorithms (`lap`, `pflap`, `sparse_lap` and `sparse_pflap`)
# perform. I will will show their speed and the quality of their outputs.

# %% [markdown]
# First I some testing images:

# %%
# using the package and TimerOutputs
using LAP_julia, TimerOutputs

# default arguments:
img, imgw, flow = gen_init();

# %% [markdown]
# See the `Basic Interaction` section or the `Public Documentation` for more advanced input generation

# %% [markdown]
# __These are the differences between the `target` (`img`) and `source` (`imgw`) images.__

# %%
imgoverlay(img, imgw, figtitle="Target vs Source")
# Out:
# Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ## `test_registration_alg`

# %% [markdown]
# This function times the registration algorithm on the inside and then test the output flow - `flow_est` and aligned source - `source_reg`.

# %%
# choose a method
method = sparse_pflap
# start a timer
timer = TimerOutput("ALG: " * string(method))
# set the keyword arguments of the method
method_kwargs = Dict(:display => false, :timer => timer, :match_source_histogram => false)
# set the arguments of the method if any
method_args = []
# start the test
flow_est, source_reg, timer, results = test_registration_alg(method,
                                                             img,
                                                             imgw,
                                                             flow,
                                                             timer=timer,
                                                             method_args=method_args,
                                                             only_flow_compare=false, # this adds source reg tests.
                                                             method_kwargs=method_kwargs);
# Out:
#  ──────────────────────────────────────────────────────────────
#                                                  Time
#                                          ──────────────────────
#             Tot / % measured:                 422ms / 94.1%
#
#  Section                         ncalls     time   %tot     avg
#  ──────────────────────────────────────────────────────────────
#  ALG: sparse_pflap                    1    397ms   100%   397ms
#    single filter pyramid level        7    376ms  94.5%  53.7ms
#      single lap at points             7    330ms  83.2%  47.2ms
#        filtering                      7    264ms  66.4%  37.7ms
#        prepare A and b                7   66.1ms  16.6%  9.44ms
#          window sum part 2           14   43.7ms  11.0%  3.12ms
#          window sum part 1           21   22.3ms  5.62%  1.06ms
#        solve linear systems           7    133μs  0.03%  19.0μs
#        calculate flow                 7   26.3μs  0.01%  3.75μs
#      image interpolation              7   24.8ms  6.23%  3.54ms
#      flow interpolation               7   19.5ms  4.91%  2.79ms
#      filter inds                      7   52.4μs  0.01%  7.48μs
#    setup                              1   20.4ms  5.13%  20.4ms
#      find edge points                 1   19.0ms  4.78%  19.0ms
#  ──────────────────────────────────────────────────────────────
#   mse            | 0.001
#   rmse           | 0.039
#   time           | 0.397
#   ncc            | 0.979
#   flow_mae       | 0.213
#   angle-rmse     | 25.89
#   angle-mae      | 2.53
#   mae            | 0.016
#   flow_rmse      | 0.055

# %% [markdown]
# #### Check the generated flow and the original flow:
# __Ground Truth:__

# %%
showflow(flow.*(-1), figtitle="Ground Truth")
# Out:
# Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# __Estimated Flow:__

# %%
showflow(flow_est, figtitle="Estimated Flow")
# Out:
# Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# ### Compare it with the `pflap` function

# %%
method = pflap
# same inputs, new timer
timer = TimerOutput("ALG: " * string(method))
flow_est, source_reg, timer, results = test_registration_alg(method,
                                                             img,
                                                             imgw,
                                                             flow,
                                                             timer=timer,
                                                             method_args=method_args,
                                                             only_flow_compare=false, # this adds source reg tests.
                                                             method_kwargs=method_kwargs);
# Out:
#  ───────────────────────────────────────────
#                               Time
#                       ──────────────────────
#    Tot / % measured:       1.81s / 99.2%
#
#  Section      ncalls     time   %tot     avg
#  ───────────────────────────────────────────
#  ALG: pflap        1    1.79s   100%   1.79s
#  ───────────────────────────────────────────
#   mse            | 0.001
#   rmse           | 0.035
#   time           | 1.792
#   ncc            | 0.982
#   flow_mae       | 0.307
#   angle-rmse     | 13.341
#   angle-mae      | 2.166
#   mae            | 0.014
#   flow_rmse      | 0.322

# %% [markdown]
# #### Check the generated flow and the original flow:
# __Ground Truth:__

# %%
showflow(flow.*(-1), figtitle="Ground Truth")
# Out:
# Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# __Estimated Flow:__

# %%
showflow(flow_est, figtitle="Estimated Flow")
# Out:
# Figure(PyObject <Figure size 2560x1920 with 1 Axes>)

# %% [markdown]
# The `time_reg_alg` is used to time the registration algorithm, when the original flow isn't known.

# %% [markdown]
# ## using the `display` keyword
# The registration algorithms have a display keyword argument, that can be set to true to output figures
# showing the `flow_est` at each iteration and print some extra debug info.

# %%
method = sparse_pflap
timer = TimerOutput("ALG: " * string(method))
method_kwargs = Dict(:display => true, :timer => timer, :match_source_histogram => false)
method_args = []
flow_est, source_reg, timer, results, (figs,) = test_registration_alg(method,
                                                                      img,
                                                                      imgw,
                                                                      flow,
                                                                      timer=timer,
                                                                      method_args=method_args,
                                                                      only_flow_compare=false, # this adds source reg tests.
                                                                      method_kwargs=method_kwargs);
# Out:
# ind count: 297
# ###################
# ITERATION: 1
# filter_half_size: 64
# inner loop iter: 1
# 	current inds: 69
# 	non NaN new estim flow vector count: 69
# ###################
# ITERATION: 2
# filter_half_size: 32
# inner loop iter: 1
# 	current inds: 157
# 	non NaN new estim flow vector count: 154
# ###################
# ITERATION: 3
# filter_half_size: 16
# inner loop iter: 1
# 	current inds: 210
# 	non NaN new estim flow vector count: 210
# ###################
# ITERATION: 4
# filter_half_size: 8
# inner loop iter: 1
# 	current inds: 243
# 	non NaN new estim flow vector count: 243
# ###################
# ITERATION: 5
# filter_half_size: 4
# inner loop iter: 1
# 	current inds: 256
# 	non NaN new estim flow vector count: 256
# ###################
# ITERATION: 6
# filter_half_size: 2
# inner loop iter: 1
# 	current inds: 272
# 	non NaN new estim flow vector count: 265
# ###################
# ITERATION: 7
# filter_half_size: 1
# inner loop iter: 1
# 	current inds: 282
# 	non NaN new estim flow vector count: 233
#  ──────────────────────────────────────────────────────────────
#                                                  Time
#                                          ──────────────────────
#             Tot / % measured:                 1.23s / 98.8%
#
#  Section                         ncalls     time   %tot     avg
#  ──────────────────────────────────────────────────────────────
#  ALG: sparse_pflap                    1    1.22s   100%   1.22s
#    single filter pyramid level        7    1.19s  98.0%   171ms
#      single lap at points             7    309ms  25.3%  44.1ms
#        filtering                      7    265ms  21.8%  37.9ms
#        prepare A and b                7   42.1ms  3.45%  6.01ms
#          window sum part 1           21   24.2ms  1.99%  1.15ms
#          window sum part 2           14   17.8ms  1.46%  1.27ms
#        solve linear systems           7    494μs  0.04%  70.6μs
#        calculate flow                 7   51.7μs  0.00%  7.38μs
#      flow interpolation               7   38.7ms  3.18%  5.53ms
#      image interpolation              7   25.9ms  2.13%  3.70ms
#      filter inds                      7   63.0μs  0.01%  9.00μs
#    setup                              1   24.4ms  2.00%  24.4ms
#      find edge points                 1   23.7ms  1.95%  23.7ms
#  ──────────────────────────────────────────────────────────────
#   mse            | 0.001
#   rmse           | 0.039
#   time           | 1.219
#   ncc            | 0.979
#   flow_mae       | 0.213
#   angle-rmse     | 25.89
#   angle-mae      | 2.53
#   mae            | 0.016
#   flow_rmse      | 0.055

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
